# %%
import pandas as pd
import numpy as np
import re
# Set display options to show full content in columns
pd.set_option('display.max_colwidth', None)
import sys
from pathlib import Path

# Get the path to the current script
current_dir = Path.cwd()

# Go one level up
current_dir = current_dir.parent

# Add the 'scripts' directory to sys.path to be able to import data_utils.py
sys.path.append(str(current_dir))

from scripts.data_utils import split_summary_methods, format_mean_std
import ast  
import matplotlib.pyplot as plt
import seaborn as sns
from autorank import autorank, plot_stats, create_report
pd.set_option('display.max_colwidth', None)
# Out:
# /home/nicolas/spectral-benchmark-bv5/scripts/data_utils.py:2: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   pd.set_option('mode.use_inf_as_na', True)

# %%
MAX_NUMBER_OF_RUNS_STOCASTIC = 3
MAX_SCENARIOS = 2 #20 for Evaluation or 2 Tuning
TYPE_WS = "params_with_p_window_size" #params_with_p_window_size or params_with_window


data = pd.read_excel(current_dir / "datasets" / "summaries" / "summary_results_sota_and_own_method_tuning_pds_and_pv.xlsx")

# Reading PV dataset showing all hyperparameters considered
order_pv = ['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9','SA1', 'SA2', 'SA3','DA1', 'DA2', 'DA3','TA1', 'TA2', 'TA3']

order_pds = ['551', '171', '115', '137', '116']


data['method_window_and_param'] = data['method_window_and_param'].str.replace("SWKNN_own", "SWKNN(own)")

data.method_window_and_param.unique()
# Out:
# array(["xStream_2000_{'depth': 25, 'n_chains': 50, 'num_components': 100}",
#        "oIF_2000_{'growth_criterion': 'fixed', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 64}",
#        "HStree_2000_{'anomaly_threshold': 0.5, 'max_depth': 15, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "HStree_2000_{'anomaly_threshold': 0.5, 'max_depth': 15, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "xStream_2000_{'depth': 15, 'n_chains': 50, 'num_components': 50}",
#        "oIF_2000_{'growth_criterion': 'adaptive', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 64}",
#        "RobustRandomCutForest_2000_{'num_trees': 4, 'tree_size': 256}",
#        "xStream_2000_{'depth': 15, 'n_chains': 50, 'num_components': 100}",
#        "KitNet_500_{'hidden_ratio': 0.75, 'learning_rate': 0.1, 'max_size_ae': 10}",
#        "SWLOF_500_{'k': 1, 'k_is_max': False, 'metric': 'cityblock', 'simplified': False}",
#        "HStree_500_{'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "KitNet_500_{'hidden_ratio': 0.75, 'learning_rate': 0.2, 'max_size_ae': 10}",
#        "IForestASD_500_{'initial_window_X': None}",
#        "xStream_500_{'depth': 25, 'n_chains': 100, 'num_components': 100}",
#        "HStree_500_{'anomaly_threshold': 0.3, 'max_depth': 10, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "SWLOF_500_{'k': 10, 'k_is_max': False, 'metric': 'cityblock', 'simplified': False}",
#        "xStream_500_{'depth': 15, 'n_chains': 100, 'num_components': 50}",
#        "xStream_500_{'depth': 15, 'n_chains': 50, 'num_components': 50}",
#        "KitNet_500_{'hidden_ratio': 0.9, 'learning_rate': 0.2, 'max_size_ae': 10}",
#        "RSHash_500_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 5}",
#        "KitNet_200_{'hidden_ratio': 0.75, 'learning_rate': 0.1, 'max_size_ae': 20}",
#        "RSHash_200_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 1}",
#        "oIF_200_{'growth_criterion': 'fixed', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 64}",
#        "IForestASD_200_{'initial_window_X': None}",
#        "HStree_200_{'anomaly_threshold': 0.5, 'max_depth': 15, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "ExactStorm_200_{'max_radius': 300}",
#        "xStream_200_{'depth': 15, 'n_chains': 100, 'num_components': 100}",
#        "xStream_200_{'depth': 25, 'n_chains': 50, 'num_components': 100}",
#        "RobustRandomCutForest_200_{'num_trees': 4, 'tree_size': 256}",
#        "HStree_2000_{'anomaly_threshold': 0.3, 'max_depth': 15, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "HStree_2000_{'anomaly_threshold': 0.3, 'max_depth': 10, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "xStream_2000_{'depth': 25, 'n_chains': 100, 'num_components': 50}",
#        "RobustRandomCutForest_500_{'num_trees': 4, 'tree_size': 512}",
#        "oIF_2000_{'growth_criterion': 'adaptive', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}",
#        "RobustRandomCutForest_200_{'num_trees': 32, 'tree_size': 512}",
#        "RobustRandomCutForest_2000_{'num_trees': 4, 'tree_size': 512}",
#        "oIF_2000_{'growth_criterion': 'adaptive', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 32}",
#        "ExactStorm_2000_{'max_radius': 900}",
#        "xStream_2000_{'depth': 15, 'n_chains': 100, 'num_components': 50}",
#        "HStree_200_{'anomaly_threshold': 0.3, 'max_depth': 15, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "HStree_200_{'anomaly_threshold': 0.3, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "xStream_200_{'depth': 15, 'n_chains': 100, 'num_components': 50}",
#        "HStree_200_{'anomaly_threshold': 0.3, 'max_depth': 15, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "HStree_200_{'anomaly_threshold': 0.5, 'max_depth': 15, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "HStree_2000_{'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "HStree_500_{'anomaly_threshold': 0.3, 'max_depth': 15, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "RSHash_500_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 1}",
#        "KitNet_500_{'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 20}",
#        "ExactStorm_200_{'max_radius': 1800}",
#        "oIF_200_{'growth_criterion': 'fixed', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 32}",
#        "oIF_200_{'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}",
#        "oIF_200_{'growth_criterion': 'adaptive', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 32}",
#        "RSHash_200_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 5}",
#        "RSHash_200_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 5}",
#        "oIF_2000_{'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}",
#        "RSHash_2000_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 5}",
#        "RSHash_2000_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}",
#        "RSHash_2000_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 1}",
#        "RSHash_500_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 5}",
#        "KitNet_500_{'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}",
#        "ExactStorm_500_{'max_radius': 0.1}",
#        "oIF_500_{'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}",
#        "RSHash_200_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}",
#        "ExactStorm_500_{'max_radius': 4000}",
#        "SWLOF_2000_{'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}",
#        "oIF_500_{'growth_criterion': 'adaptive', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 32}",
#        "RSHash_2000_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 5}",
#        "xStream_200_{'depth': 25, 'n_chains': 100, 'num_components': 50}",
#        "oIF_2000_{'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 32}",
#        "mDragStream_200_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'euclidean'}",
#        "oIF_500_{'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 32}",
#        "oIF_500_{'growth_criterion': 'fixed', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 32}",
#        "mDragStream_500_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'mahalanobis'}",
#        "oIF_500_{'growth_criterion': 'adaptive', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 64}",
#        "RSHash_200_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 5}",
#        "ExactStorm_200_{'max_radius': 900}",
#        "mDragStream_2000_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'euclidean'}",
#        "RobustRandomCutForest_2000_{'num_trees': 32, 'tree_size': 256}",
#        "mDragStream_2000_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'euclidean'}",
#        "RobustRandomCutForest_200_{'num_trees': 4, 'tree_size': 512}",
#        "ExactStorm_500_{'max_radius': 900}",
#        "HStree_2000_{'anomaly_threshold': 0.3, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "oIF_500_{'growth_criterion': 'adaptive', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}",
#        "oIF_200_{'growth_criterion': 'adaptive', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}",
#        "KitNet_2000_{'hidden_ratio': 0.75, 'learning_rate': 0.1, 'max_size_ae': 20}",
#        "xStream_200_{'depth': 25, 'n_chains': 50, 'num_components': 50}",
#        "RSHash_500_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 5}",
#        "RSHash_500_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 5}",
#        "KitNet_500_{'hidden_ratio': 0.75, 'learning_rate': 0.2, 'max_size_ae': 20}",
#        "mDragStream_500_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}",
#        "xStream_500_{'depth': 25, 'n_chains': 50, 'num_components': 100}",
#        "xStream_500_{'depth': 25, 'n_chains': 50, 'num_components': 50}",
#        "HStree_200_{'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "RSHash_500_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 1}",
#        "xStream_500_{'depth': 15, 'n_chains': 100, 'num_components': 100}",
#        "KitNet_200_{'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}",
#        "ExactStorm_500_{'max_radius': 1800}",
#        "RobustRandomCutForest_500_{'num_trees': 32, 'tree_size': 256}",
#        "HStree_500_{'anomaly_threshold': 0.3, 'max_depth': 15, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "RSHash_2000_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 1}",
#        "HStree_2000_{'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "oIF_2000_{'growth_criterion': 'fixed', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 32}",
#        "xStream_500_{'depth': 25, 'n_chains': 100, 'num_components': 50}",
#        "xStream_2000_{'depth': 15, 'n_chains': 100, 'num_components': 100}",
#        "ExactStorm_2000_{'max_radius': 0.1}",
#        "HStree_200_{'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "mDragStream_2000_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}",
#        "oIF_200_{'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 32}",
#        "KitNet_200_{'hidden_ratio': 0.75, 'learning_rate': 0.1, 'max_size_ae': 10}",
#        "mDragStream_200_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'mahalanobis'}",
#        "oIF_500_{'growth_criterion': 'adaptive', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 32}",
#        "ExactStorm_2000_{'max_radius': 4000}",
#        "IForestASD_2000_{'initial_window_X': None}",
#        "RobustRandomCutForest_2000_{'num_trees': 32, 'tree_size': 512}",
#        "ExactStorm_200_{'max_radius': 0.1}",
#        "HStree_500_{'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "mDragStream_200_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'mahalanobis'}",
#        "KitNet_2000_{'hidden_ratio': 0.9, 'learning_rate': 0.2, 'max_size_ae': 10}",
#        "HStree_500_{'anomaly_threshold': 0.3, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "RSHash_2000_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}",
#        "mDragStream_2000_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}",
#        "HStree_2000_{'anomaly_threshold': 0.3, 'max_depth': 15, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "HStree_500_{'anomaly_threshold': 0.5, 'max_depth': 15, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "RSHash_200_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 1}",
#        "HStree_200_{'anomaly_threshold': 0.3, 'max_depth': 10, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "KitNet_200_{'hidden_ratio': 0.75, 'learning_rate': 0.2, 'max_size_ae': 10}",
#        "SWLOF_200_{'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}",
#        "mDragStream_200_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'mahalanobis'}",
#        "RobustRandomCutForest_200_{'num_trees': 32, 'tree_size': 256}",
#        "KitNet_200_{'hidden_ratio': 0.9, 'learning_rate': 0.2, 'max_size_ae': 10}",
#        "mDragStream_500_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'mahalanobis'}",
#        "RSHash_2000_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 5}",
#        "KitNet_2000_{'hidden_ratio': 0.75, 'learning_rate': 0.2, 'max_size_ae': 20}",
#        "oIF_2000_{'growth_criterion': 'adaptive', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 32}",
#        "RSHash_500_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}",
#        "xStream_200_{'depth': 15, 'n_chains': 50, 'num_components': 50}",
#        "RSHash_200_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 5}",
#        "RobustRandomCutForest_500_{'num_trees': 4, 'tree_size': 256}",
#        "HStree_500_{'anomaly_threshold': 0.5, 'max_depth': 15, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "oIF_200_{'growth_criterion': 'adaptive', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 64}",
#        "xStream_200_{'depth': 25, 'n_chains': 100, 'num_components': 100}",
#        "mDragStream_200_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'euclidean'}",
#        "oIF_200_{'growth_criterion': 'adaptive', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 32}",
#        "xStream_2000_{'depth': 25, 'n_chains': 50, 'num_components': 50}",
#        "RSHash_2000_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 5}",
#        "mDragStream_500_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'mahalanobis'}",
#        "ExactStorm_200_{'max_radius': 4000}",
#        "xStream_200_{'depth': 15, 'n_chains': 50, 'num_components': 100}",
#        "KitNet_2000_{'hidden_ratio': 0.75, 'learning_rate': 0.2, 'max_size_ae': 10}",
#        "mDragStream_500_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'euclidean'}",
#        "RSHash_200_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}",
#        "mDragStream_500_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}",
#        "mDragStream_500_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'euclidean'}",
#        "xStream_500_{'depth': 15, 'n_chains': 50, 'num_components': 100}",
#        "KitNet_200_{'hidden_ratio': 0.75, 'learning_rate': 0.2, 'max_size_ae': 20}",
#        "RSHash_500_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}",
#        "RobustRandomCutForest_500_{'num_trees': 32, 'tree_size': 512}",
#        "SWLOF_500_{'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}",
#        "mDragStream_2000_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'mahalanobis'}",
#        "KitNet_200_{'hidden_ratio': 0.9, 'learning_rate': 0.2, 'max_size_ae': 20}",
#        "SWLOF_200_{'k': 10, 'k_is_max': False, 'metric': 'cityblock', 'simplified': False}",
#        "ExactStorm_500_{'max_radius': 300}",
#        "KitNet_2000_{'hidden_ratio': 0.9, 'learning_rate': 0.2, 'max_size_ae': 20}",
#        "oIF_500_{'growth_criterion': 'fixed', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 64}",
#        "SWLOF_200_{'k': 1, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}",
#        "mDragStream_200_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}",
#        "mDragStream_200_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}",
#        "KitNet_2000_{'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}",
#        "mDragStream_200_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'euclidean'}",
#        "KitNet_500_{'hidden_ratio': 0.75, 'learning_rate': 0.1, 'max_size_ae': 20}",
#        "mDragStream_2000_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'mahalanobis'}",
#        "xStream_2000_{'depth': 25, 'n_chains': 100, 'num_components': 100}",
#        "mDragStream_2000_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'mahalanobis'}",
#        "KitNet_2000_{'hidden_ratio': 0.75, 'learning_rate': 0.1, 'max_size_ae': 10}",
#        "ExactStorm_2000_{'max_radius': 1800}",
#        "SWLOF_2000_{'k': 10, 'k_is_max': False, 'metric': 'cityblock', 'simplified': False}",
#        "KitNet_200_{'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 20}",
#        "KitNet_2000_{'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 20}",
#        "mDragStream_500_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'euclidean'}",
#        "SWLOF_2000_{'k': 1, 'k_is_max': False, 'metric': 'cityblock', 'simplified': False}",
#        "SWLOF_2000_{'k': 1, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}",
#        "mDragStream_2000_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'euclidean'}",
#        "ExactStorm_2000_{'max_radius': 300}",
#        "KitNet_500_{'hidden_ratio': 0.9, 'learning_rate': 0.2, 'max_size_ae': 20}",
#        "SWLOF_200_{'k': 1, 'k_is_max': False, 'metric': 'cityblock', 'simplified': False}",
#        "SWLOF_500_{'k': 1, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}",
#        "oIF_840_{'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}",
#        "xStream_210_{'depth': 15, 'n_chains': 50, 'num_components': 50}",
#        "RSHash_210_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 5}",
#        "SWLOF_84_{'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}",
#        "ExactStorm_84_{'max_radius': 0.1}",
#        "xStream_840_{'depth': 25, 'n_chains': 50, 'num_components': 100}",
#        "RobustRandomCutForest_210_{'num_trees': 4, 'tree_size': 512}",
#        "ExactStorm_210_{'max_radius': 0.1}",
#        "RSHash_84_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 1}",
#        "HStree_840_{'anomaly_threshold': 0.3, 'max_depth': 10, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "HStree_840_{'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "RSHash_840_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 5}",
#        "HStree_210_{'anomaly_threshold': 0.3, 'max_depth': 15, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "HStree_210_{'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "xStream_210_{'depth': 25, 'n_chains': 50, 'num_components': 100}",
#        "KitNet_210_{'hidden_ratio': 0.75, 'learning_rate': 0.2, 'max_size_ae': 10}",
#        "RSHash_840_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 1}",
#        "oIF_840_{'growth_criterion': 'adaptive', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 32}",
#        "xStream_210_{'depth': 15, 'n_chains': 50, 'num_components': 100}",
#        "oIF_84_{'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}",
#        "RSHash_84_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 1}",
#        "RSHash_84_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}",
#        "SWLOF_840_{'k': 1, 'k_is_max': False, 'metric': 'cityblock', 'simplified': False}",
#        "HStree_84_{'anomaly_threshold': 0.3, 'max_depth': 15, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "KitNet_84_{'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 20}",
#        "oIF_84_{'growth_criterion': 'adaptive', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 32}",
#        "oIF_210_{'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}",
#        "xStream_840_{'depth': 25, 'n_chains': 100, 'num_components': 100}",
#        "KitNet_84_{'hidden_ratio': 0.75, 'learning_rate': 0.1, 'max_size_ae': 10}",
#        "RSHash_84_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 5}",
#        "xStream_84_{'depth': 25, 'n_chains': 50, 'num_components': 100}",
#        "HStree_840_{'anomaly_threshold': 0.5, 'max_depth': 15, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "mDragStream_840_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'mahalanobis'}",
#        "HStree_840_{'anomaly_threshold': 0.3, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "SWLOF_840_{'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}",
#        "oIF_840_{'growth_criterion': 'fixed', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 32}",
#        "RSHash_210_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}",
#        "oIF_210_{'growth_criterion': 'fixed', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 32}",
#        "HStree_210_{'anomaly_threshold': 0.3, 'max_depth': 15, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "RobustRandomCutForest_84_{'num_trees': 4, 'tree_size': 512}",
#        "oIF_210_{'growth_criterion': 'adaptive', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 32}",
#        "xStream_210_{'depth': 15, 'n_chains': 100, 'num_components': 50}",
#        "HStree_840_{'anomaly_threshold': 0.3, 'max_depth': 15, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "RobustRandomCutForest_84_{'num_trees': 4, 'tree_size': 256}",
#        "RobustRandomCutForest_210_{'num_trees': 4, 'tree_size': 256}",
#        "xStream_210_{'depth': 25, 'n_chains': 100, 'num_components': 50}",
#        "RobustRandomCutForest_210_{'num_trees': 32, 'tree_size': 512}",
#        "RSHash_840_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 5}",
#        "mDragStream_84_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'euclidean'}",
#        "IForestASD_84_{'initial_window_X': None}",
#        "RobustRandomCutForest_84_{'num_trees': 32, 'tree_size': 512}",
#        "mDragStream_84_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}",
#        "mDragStream_84_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'euclidean'}",
#        "RSHash_210_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 5}",
#        "xStream_84_{'depth': 25, 'n_chains': 100, 'num_components': 100}",
#        "oIF_84_{'growth_criterion': 'adaptive', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 32}",
#        "RobustRandomCutForest_840_{'num_trees': 32, 'tree_size': 256}",
#        "mDragStream_84_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'mahalanobis'}",
#        "xStream_84_{'depth': 25, 'n_chains': 50, 'num_components': 50}",
#        "RSHash_84_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 5}",
#        "oIF_84_{'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 32}",
#        "KitNet_840_{'hidden_ratio': 0.9, 'learning_rate': 0.2, 'max_size_ae': 20}",
#        "ExactStorm_840_{'max_radius': 900}",
#        "oIF_210_{'growth_criterion': 'adaptive', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}",
#        "HStree_84_{'anomaly_threshold': 0.5, 'max_depth': 15, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "xStream_84_{'depth': 15, 'n_chains': 100, 'num_components': 100}",
#        "oIF_84_{'growth_criterion': 'adaptive', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}",
#        "RSHash_84_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}",
#        "xStream_84_{'depth': 25, 'n_chains': 100, 'num_components': 50}",
#        "RSHash_840_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 1}",
#        "HStree_84_{'anomaly_threshold': 0.3, 'max_depth': 15, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "RobustRandomCutForest_840_{'num_trees': 4, 'tree_size': 256}",
#        "RSHash_840_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}",
#        "xStream_840_{'depth': 15, 'n_chains': 50, 'num_components': 100}",
#        "xStream_84_{'depth': 15, 'n_chains': 50, 'num_components': 50}",
#        "KitNet_210_{'hidden_ratio': 0.75, 'learning_rate': 0.2, 'max_size_ae': 20}",
#        "KitNet_210_{'hidden_ratio': 0.9, 'learning_rate': 0.2, 'max_size_ae': 20}",
#        "oIF_840_{'growth_criterion': 'fixed', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 64}",
#        "SWLOF_210_{'k': 1, 'k_is_max': False, 'metric': 'cityblock', 'simplified': False}",
#        "SWLOF_210_{'k': 1, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}",
#        "IForestASD_210_{'initial_window_X': None}",
#        "ExactStorm_210_{'max_radius': 1800}",
#        "mDragStream_840_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'mahalanobis'}",
#        "RSHash_840_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 5}",
#        "HStree_210_{'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "HStree_84_{'anomaly_threshold': 0.3, 'max_depth': 10, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "KitNet_84_{'hidden_ratio': 0.75, 'learning_rate': 0.2, 'max_size_ae': 10}",
#        "xStream_840_{'depth': 15, 'n_chains': 100, 'num_components': 100}",
#        "xStream_210_{'depth': 25, 'n_chains': 50, 'num_components': 50}",
#        "xStream_840_{'depth': 25, 'n_chains': 50, 'num_components': 50}",
#        "KitNet_840_{'hidden_ratio': 0.75, 'learning_rate': 0.2, 'max_size_ae': 20}",
#        "ExactStorm_840_{'max_radius': 1800}",
#        "RSHash_84_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 5}",
#        "KitNet_210_{'hidden_ratio': 0.75, 'learning_rate': 0.1, 'max_size_ae': 10}",
#        "xStream_840_{'depth': 15, 'n_chains': 100, 'num_components': 50}",
#        "mDragStream_840_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'euclidean'}",
#        "oIF_84_{'growth_criterion': 'adaptive', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 64}",
#        "KitNet_840_{'hidden_ratio': 0.75, 'learning_rate': 0.1, 'max_size_ae': 20}",
#        "oIF_840_{'growth_criterion': 'adaptive', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 64}",
#        "RSHash_84_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 5}",
#        "oIF_210_{'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 32}",
#        "RSHash_210_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 1}",
#        "mDragStream_210_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'mahalanobis'}",
#        "KitNet_840_{'hidden_ratio': 0.9, 'learning_rate': 0.2, 'max_size_ae': 10}",
#        "oIF_210_{'growth_criterion': 'adaptive', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 32}",
#        "RobustRandomCutForest_840_{'num_trees': 4, 'tree_size': 512}",
#        "RSHash_210_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 5}",
#        "oIF_84_{'growth_criterion': 'fixed', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 64}",
#        "SWLOF_84_{'k': 1, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}",
#        "RobustRandomCutForest_210_{'num_trees': 32, 'tree_size': 256}",
#        "RSHash_210_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}",
#        "HStree_210_{'anomaly_threshold': 0.5, 'max_depth': 15, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "SWLOF_840_{'k': 10, 'k_is_max': False, 'metric': 'cityblock', 'simplified': False}",
#        "mDragStream_84_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'euclidean'}",
#        "HStree_840_{'anomaly_threshold': 0.3, 'max_depth': 15, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "KitNet_210_{'hidden_ratio': 0.75, 'learning_rate': 0.1, 'max_size_ae': 20}",
#        "HStree_840_{'anomaly_threshold': 0.5, 'max_depth': 15, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "oIF_840_{'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 32}",
#        "KitNet_840_{'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}",
#        "IForestASD_840_{'initial_window_X': None}",
#        "HStree_840_{'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "RSHash_210_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 5}",
#        "RobustRandomCutForest_840_{'num_trees': 32, 'tree_size': 512}",
#        "KitNet_840_{'hidden_ratio': 0.75, 'learning_rate': 0.1, 'max_size_ae': 10}",
#        "oIF_210_{'growth_criterion': 'adaptive', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 64}",
#        "KitNet_210_{'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 20}",
#        "KitNet_210_{'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}",
#        "oIF_840_{'growth_criterion': 'adaptive', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 32}",
#        "mDragStream_840_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}",
#        "oIF_840_{'growth_criterion': 'adaptive', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}",
#        "RSHash_210_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 100, 'num_hash_fns': 1}",
#        "HStree_84_{'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "HStree_210_{'anomaly_threshold': 0.3, 'max_depth': 10, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "xStream_84_{'depth': 15, 'n_chains': 50, 'num_components': 100}",
#        "HStree_84_{'anomaly_threshold': 0.5, 'max_depth': 15, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "HStree_84_{'anomaly_threshold': 0.3, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "ExactStorm_210_{'max_radius': 300}",
#        "RobustRandomCutForest_84_{'num_trees': 32, 'tree_size': 256}",
#        "HStree_210_{'anomaly_threshold': 0.5, 'max_depth': 15, 'number_of_trees': 15, 'size_limit': 0.1}",
#        "xStream_84_{'depth': 15, 'n_chains': 100, 'num_components': 50}",
#        "SWLOF_84_{'k': 10, 'k_is_max': False, 'metric': 'cityblock', 'simplified': False}",
#        "mDragStream_210_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'mahalanobis'}",
#        "xStream_210_{'depth': 15, 'n_chains': 100, 'num_components': 100}",
#        "SWLOF_210_{'k': 10, 'k_is_max': False, 'metric': 'cityblock', 'simplified': False}",
#        "oIF_210_{'growth_criterion': 'fixed', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 64}",
#        "mDragStream_210_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}",
#        "xStream_840_{'depth': 15, 'n_chains': 50, 'num_components': 50}",
#        "HStree_210_{'anomaly_threshold': 0.3, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "mDragStream_84_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'mahalanobis'}",
#        "oIF_84_{'growth_criterion': 'fixed', 'max_leaf_samples': 32, 'n_jobs': -1, 'num_trees': 32}",
#        "SWLOF_210_{'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}",
#        "SWLOF_84_{'k': 1, 'k_is_max': False, 'metric': 'cityblock', 'simplified': False}",
#        "xStream_840_{'depth': 25, 'n_chains': 100, 'num_components': 50}",
#        "ExactStorm_84_{'max_radius': 300}",
#        "KitNet_84_{'hidden_ratio': 0.75, 'learning_rate': 0.2, 'max_size_ae': 20}",
#        "KitNet_840_{'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 20}",
#        "ExactStorm_84_{'max_radius': 900}",
#        "mDragStream_210_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'mahalanobis'}",
#        "HStree_84_{'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "KitNet_210_{'hidden_ratio': 0.9, 'learning_rate': 0.2, 'max_size_ae': 10}",
#        "ExactStorm_840_{'max_radius': 0.1}",
#        "RSHash_840_{'decay': 0.015, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}",
#        "KitNet_84_{'hidden_ratio': 0.75, 'learning_rate': 0.1, 'max_size_ae': 20}",
#        "mDragStream_210_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}",
#        "mDragStream_210_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'euclidean'}",
#        "mDragStream_840_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}",
#        "mDragStream_84_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}",
#        "ExactStorm_210_{'max_radius': 4000}",
#        "KitNet_84_{'hidden_ratio': 0.9, 'learning_rate': 0.2, 'max_size_ae': 10}",
#        "mDragStream_84_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'mahalanobis'}",
#        "ExactStorm_84_{'max_radius': 1800}",
#        "ExactStorm_210_{'max_radius': 900}",
#        "RSHash_840_{'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 5}",
#        "mDragStream_840_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'euclidean'}",
#        "xStream_210_{'depth': 25, 'n_chains': 100, 'num_components': 100}",
#        "SWLOF_840_{'k': 1, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}",
#        "ExactStorm_84_{'max_radius': 4000}",
#        "mDragStream_210_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'euclidean'}",
#        "KitNet_84_{'hidden_ratio': 0.9, 'learning_rate': 0.2, 'max_size_ae': 20}",
#        "ExactStorm_840_{'max_radius': 300}",
#        "mDragStream_210_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'euclidean'}",
#        "mDragStream_840_{'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'mahalanobis'}",
#        "OnlineBootKNN_200_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_200_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_200_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_200_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_200_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_2000_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_500_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_500_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_2000_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_500_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_500_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_200_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_500_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_2000_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_200_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "mDragStream_840_{'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'euclidean'}",
#        "ExactStorm_840_{'max_radius': 4000}",
#        "OnlineBootKNN_2000_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}",
#        "KitNet_840_{'hidden_ratio': 0.75, 'learning_rate': 0.2, 'max_size_ae': 10}",
#        "OnlineBootKNN_200_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_200_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_500_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}",
#        "KitNet_84_{'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}",
#        "OnlineBootKNN_2000_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_200_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_500_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_2000_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_2000_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_2000_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_2000_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_200_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_200_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}",
#        "SWKNN_200_{'k': 1, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}",
#        "OnlineBootKNN_2000_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_500_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_500_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_200_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_500_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_500_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_2000_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_500_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_200_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_2000_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_500_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
# ...
#        "OnlineBootKNN_840_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_840_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "SWKNN_840_{'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}",
#        "OnlineBootKNN_84_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_210_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_84_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_210_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_840_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_210_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_840_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_210_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_84_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_210_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_210_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_84_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_210_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_210_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_84_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_840_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_840_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_84_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_210_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_840_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_840_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_84_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_840_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_84_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_840_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_840_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_210_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_84_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_210_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_840_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_840_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_84_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_210_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_840_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_840_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_84_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "SWKNN_210_{'k': 1, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}",
#        "OnlineBootKNN_840_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_84_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_210_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}",
#        "OnlineBootKNN_210_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "SWKNN_840_{'k': 1, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}",
#        "OnlineBootKNN_210_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_84_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}",
#        "SWKNN_84_{'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}",
#        "OnlineBootKNN_840_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "OnlineBootKNN_84_{'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}",
#        "SWKNN_840_{'k': 50, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}"],
#       dtype=object)

# %%
# Find duplicates for the same iteration and the same experiment
duplicates = data[["iteration", "cod_scenario", "method_window_and_param", "count_cleaned_score"]].duplicated(keep=False)
data[duplicates][["iteration", "cod_scenario", "method_window_and_param", "count_cleaned_score"]].sort_values(by=["method_window_and_param"])
# Out:
# Empty DataFrame
# Columns: [iteration, cod_scenario, method_window_and_param, count_cleaned_score]
# Index: []

# %%
# Summary of datasets used
pivot = data.pivot_table(values=["count_cleaned_score", "count_anomalies"], index=["cod_scenario"], aggfunc='mean')
pivot['percentage_anomalies'] = (pivot['count_anomalies'] / pivot['count_cleaned_score']) * 100
pivot
# Out:
#               count_anomalies  count_cleaned_score  percentage_anomalies
# cod_scenario
# 116                     492.0              10000.0              4.920000
# DA3                     600.0               4200.0             14.285714

# %%
# Adjusting format and creating new columns for analysis in the dataset read

# Extracting new columns for the method, window_size, parameters
data[['method',"window_size", 'parameters']] = data['method_window_and_param'].apply(
    lambda x: pd.Series(split_summary_methods(x))
)

# Creating new column params_with_window
data["params_with_p_window_size"] = "{'p_window_size': " + data["p_window_size"].astype(str)+data["parameters"].str.replace("{", ", ", regex=False)
data["params_with_p_window_size"] = data["params_with_p_window_size"].str.replace("}_{", ",", regex=False)

data["params_with_window"] = "{'window_size': " + data["window_size"].astype(str)+data["parameters"].str.replace("{", ", ", regex=False)
data["params_with_window"] = data["params_with_window"].str.replace("}_{", ",", regex=False)

# Define your list of non-stochastic methods
non_stochastic_methods = ["SWKNN", "SWKNN_own", "SWLOF", "KitNet", "ExactStorm", "mDragStream"]

# Create the 'stochastic' column
data['stochastic'] = data['method'].apply(
    lambda x: 'N' if x in non_stochastic_methods else 'Y')

# Shortening the name of the methods
new_method_name = {"xStream":"XStream", "RSHash":"RSHash", "IForestASD":"IFASD", "RobustRandomCutForest":"RRCF", "KitNet":"KitNet", "ExactStorm":"EStorm","oIF":"OIF", "HStree":"HStree", "OnlineBootKNN":"OBKNN"} 
data["method"] = data['method'].replace(new_method_name)
data["method_with_param"] = data['method']+"_"+data["parameters"]

#Separating mDragstream with Mahalanobis and Euclidean Distance
# Case 1: Euclidean
mask_euc = (data['method'] == 'mDragStream') & \
           (data['params_with_window'].str.contains('euclidean', case=False, na=False))
data.loc[mask_euc, 'method'] = 'mDragStream (Euc)'

# Case 2: Mahalanobis
mask_mah = (data['method'] == 'mDragStream') & \
           (data['params_with_window'].str.contains('mahalanobis', case=False, na=False))
data.loc[mask_mah, 'method'] = 'mDragStream (Mah)'

#Separating OnlineBootKNN with None, Z-normalization or SQRT transformation
# Case 1: None
mask_none = (data['method'] == 'OBKNN') & \
           (data['params_with_window'].str.contains('NONE', case=False, na=False))
data.loc[mask_none, 'method'] = 'OBKNN (TNone)'

# Case 2: ZNormalization
mask_znorm = (data['method'] == 'OBKNN') & \
           (data['params_with_window'].str.contains('ZNORM', case=False, na=False))
data.loc[mask_znorm, 'method'] = 'OBKNN (TZnorm)'

# Case 2: ZNormalization
mask_sqrt = (data['method'] == 'OBKNN') & \
           (data['params_with_window'].str.contains('SQRT', case=False, na=False))
data.loc[mask_sqrt, 'method'] = 'OBKNN (TSqrt)'

# Including the year of publication of the methods
method_and_year = {"XStream":"2018", "RSHash":"2011", "IFASD":"2013", "RRCF":"2016", "KitNet":"2018", "EStorm":"2007","OIF":"2024", "HStree":"2011", "OBKNN (TNone)":"2025", "OBKNN (TZnorm)":"2025", "OBKNN (TSqrt)":"2025", "BKNN":"2025", "SWKNN":"2000","SWLOF":"2000", "SWKNN_own":"2025", "mDragStream (Mah)":"2025", "mDragStream (Euc)":"2025"} 
data["method_and_year"] = data['method'].map(lambda x: f"{x} ({method_and_year.get(x, 'Unknown')})")

# %%
# Summary (before data filtering) of Scenarios, number of runs and hyperparameters considered
pivot = data.pivot_table(
    values=[TYPE_WS,"window_size"], 
    index=["cod_scenario","iteration"], 
    columns=['method'], 
    #aggfunc=['count','nunique']
    aggfunc=['nunique']
)
pivot
# Out:
#                                          nunique                      \
#                        params_with_p_window_size
# method                                    EStorm HStree IFASD KitNet
# cod_scenario iteration
# 116          0                              15.0   24.0   3.0   24.0
#              1                               NaN   24.0   3.0    NaN
#              2                               NaN   24.0   3.0    NaN
# DA3          0                              15.0   24.0   3.0   24.0
#              1                               NaN   24.0   3.0    NaN
#              2                               NaN   24.0   3.0    NaN
#
#                                                                               \
#
# method                 OBKNN (TNone) OBKNN (TZnorm)   OIF  RRCF RSHash SWKNN
# cod_scenario iteration
# 116          0                  48.0           48.0  24.0  12.0   24.0   9.0
#              1                  48.0           48.0  24.0  12.0   24.0   NaN
#              2                  48.0           48.0  24.0  12.0   24.0   NaN
# DA3          0                  48.0           48.0  24.0  12.0   24.0   9.0
#              1                  48.0           48.0  24.0  12.0   24.0   NaN
#              2                  48.0           48.0  24.0  12.0   24.0   NaN
#
#                         ...                                                \
#                         ...   window_size
# method                  ... OBKNN (TNone) OBKNN (TZnorm)  OIF RRCF RSHash
# cod_scenario iteration  ...
# 116          0          ...           3.0            3.0  3.0  3.0    3.0
#              1          ...           3.0            3.0  3.0  3.0    3.0
#              2          ...           3.0            3.0  3.0  3.0    3.0
# DA3          0          ...           3.0            3.0  3.0  3.0    3.0
#              1          ...           3.0            3.0  3.0  3.0    3.0
#              2          ...           3.0            3.0  3.0  3.0    3.0
#
#
#
# method                 SWKNN SWLOF XStream mDragStream (Euc) mDragStream (Mah)
# cod_scenario iteration
# 116          0           3.0   3.0     3.0               3.0               3.0
#              1           NaN   NaN     3.0               NaN               NaN
#              2           NaN   NaN     3.0               NaN               NaN
# DA3          0           3.0   3.0     3.0               3.0               3.0
#              1           NaN   NaN     3.0               NaN               NaN
#              2           NaN   NaN     3.0               NaN               NaN
#
# [6 rows x 28 columns]

# %%
params_obknn = data[data['method']=="OBKNN"][TYPE_WS].unique()
len(params_obknn)
# Out:
# 0

# %%
params_obknn
# Out:
# array([], dtype=object)

# %%
# Obtaining the best hyperparameters (for all window sizes)
# 1. average results over all iterations and all scenarios
averaged_results = data.groupby(['method', 'parameters', 'cod_scenario'])['raw_pr_auc'].agg(
    mean_auc_pr='mean',
    std_auc_pr='std',
    n_runs='count'
).reset_index()
# 2. average results for each method and hyperparameter (including window size) for all scenarios
summary = averaged_results.groupby(['method','parameters']).agg(
    mean_auc_pr=('mean_auc_pr', 'mean'),
    std_auc_pr=('std_auc_pr', 'mean'),
    n_scenarios=('mean_auc_pr', 'count'),
    #n_experiments=('n_runs', 'sum')
).reset_index()


#summary.sort_values(['mean_auc_pr','std_auc_pr'], ascending=[False, True]).head(10)

# Obtaining the best hyperparameters (for all window sizes)
# 3. Select the highest AUC_PR per method and hyperparameter
best_results = (
    summary
    .sort_values(['mean_auc_pr','std_auc_pr'], ascending=[False, True])
    .groupby('method')
    .head(1)
)
#best_params = best_results['parameters'].unique().tolist()
#best_results

# %%
# Obtaining the best window size (for all hyperparameters)
# 1. average results over all iterations and all scenarios
averaged_results = data.groupby(['method', 'p_window_size', 'cod_scenario'])['raw_pr_auc'].agg(
    mean_auc_pr='mean',
    std_auc_pr='std',
    n_runs='count'
).reset_index()
# 2. average results for each method and hyperparameter (including window size) for all scenarios
summary = averaged_results.groupby(['method','p_window_size']).agg(
    mean_auc_pr=('mean_auc_pr', 'mean'),
    std_auc_pr=('std_auc_pr', 'mean'),
    n_scenarios=('mean_auc_pr', 'count'),
    #n_experiments=('n_runs', 'sum')
).reset_index()

#summary.sort_values(['mean_auc_pr','std_auc_pr'], ascending=[False, True]).head(10)

# Obtaining the best window size (for all hyperparameters)
# 3. Select the highest AUC_PR per method and hyperparameter
best_results = (
    summary
    .sort_values(['mean_auc_pr','std_auc_pr'], ascending=[False, True])
    .groupby('method')
    .head(1)
)
#best_ws = best_results[TYPE_WINDOW_SIZE].unique().tolist()
#best_results

# %%
# Obtaining the hyperparameters that are complete for analysis
averaged_results = data.groupby(['method', 'stochastic', TYPE_WS, 'cod_scenario'])['raw_pr_auc'].agg(
    n_runs='count',
).reset_index()

# Condition 1: Stochastic methods must have MAX_NUMBER_OF_RUNS_STOCASTIC
cond_stochastic = (averaged_results['n_runs'] == MAX_NUMBER_OF_RUNS_STOCASTIC) & (averaged_results['stochastic'] == 'Y')

# Condition 2: Non-Stochastic methods must have 1 run
cond_non_stochastic = (averaged_results['n_runs'] == 1) & (averaged_results['stochastic'] == 'N')

# Apply the combined filter using | (OR)
# Let's call this new variable 'filtered_results'
filtered_results = averaged_results[cond_stochastic | cond_non_stochastic]

# Now, 'filtered_results' contains the data you wanted to see
# You can uncomment the next line to inspect it:
# print("--- Filtered Results (Step 1) ---")
# display(filtered_results)


# Now, aggregate the *filtered* results to count complete scenarios
scenario_counts = filtered_results.groupby(['method', TYPE_WS])['cod_scenario'].agg(
    n_scenarios='nunique'
).reset_index()

# Get the final list of complete hyperparameters
scenario_counts = scenario_counts[scenario_counts.n_scenarios==MAX_SCENARIOS]
hyperparameters_complete = scenario_counts[TYPE_WS]

# %%
#Applying filters to analyse data

#regex_filter = "|".join(["'transf': 'None'", "shingle_size",'SWKNN'])
regex_filter = "|".join([""])

filtered_data = data[data['method_window_and_param'].str.contains(regex_filter, regex=True)]

# Filter rows where 'parameters' column contains any of the best_params
#filtered_data = filtered_data[filtered_data['params_with_window'].isin(best_params)]


#filtered_data = filtered_data[filtered_data['method'].str.contains("std_p")]
#filtered_data = filtered_data[filtered_data['method'].str.contains("None|FOD|SOD|DIL|QUANT")]
#filtered_data = filtered_data[filtered_data['method'].str.contains("QUANT")]
#filtered_data = filtered_data[filtered_data.method.str.contains("OnlineBootGP|OnlineBootKNN")]

# Now, sort the data based on the 'scenario' column
filtered_data = filtered_data.sort_values(by='cod_scenario')

#filtered_data = filtered_data[~filtered_data.window_size.isin(["60"])]

#filtered_data = filtered_data[filtered_data.method.isin(["ExactStorm", "OnlineBootKNN"])]
filtered_data = filtered_data[~filtered_data.cod_scenario.isin(["A10", "A11","A12","TA1", "TA2","TA3"])]
#filtered_data = filtered_data[~filtered_data.cod_scenario.isin(["116"])]
#filtered_data = filtered_data[filtered_data.scenario.isin(["A1", "A2","A3","A4", "A5","A6","A7", "A8","A9"])]


#filtered_data = filtered_data[filtered_data['method_window_and_param'].isin(PARAMS)]
filtered_data = filtered_data[filtered_data[TYPE_WS].isin(hyperparameters_complete)]

#total_scenarios = len(filtered_data.scenario.unique())
# Compute overall mean, std, and count across all datasets
# Exclude the rows where the number of scenarios is not equal to total_scenarios
#summary = summary[summary.n_scenarios==total_scenarios]

#filtered_data.head(10)

# %%
# Summary of datasets used (after data filtering)
pivot = filtered_data.pivot_table(values=["count_cleaned_score", "count_anomalies"], index=["cod_scenario"], aggfunc='mean')

pivot['percentage_anomalies'] = (pivot['count_anomalies'] / pivot['count_cleaned_score']) * 100
pivot
# Out:
#               count_anomalies  count_cleaned_score  percentage_anomalies
# cod_scenario
# 116                     492.0              10000.0              4.920000
# DA3                     600.0               4200.0             14.285714

# %%
# Summary (after data filtering) of Scenarios, number of runs and hyperparameters considered
pivot = filtered_data.pivot_table(
    values=[TYPE_WS,"window_size"], 
    index=["cod_scenario","iteration"], 
    columns=['method'], 
    #aggfunc=['count','nunique']
    aggfunc=['nunique']
)
pivot
# Out:
#                                          nunique                      \
#                        params_with_p_window_size
# method                                    EStorm HStree IFASD KitNet
# cod_scenario iteration
# 116          0                              15.0   24.0   3.0   24.0
#              1                               NaN   24.0   3.0    NaN
#              2                               NaN   24.0   3.0    NaN
# DA3          0                              15.0   24.0   3.0   24.0
#              1                               NaN   24.0   3.0    NaN
#              2                               NaN   24.0   3.0    NaN
#
#                                                                               \
#
# method                 OBKNN (TNone) OBKNN (TZnorm)   OIF  RRCF RSHash SWKNN
# cod_scenario iteration
# 116          0                  48.0           48.0  24.0  12.0   24.0   9.0
#              1                  48.0           48.0  24.0  12.0   24.0   NaN
#              2                  48.0           48.0  24.0  12.0   24.0   NaN
# DA3          0                  48.0           48.0  24.0  12.0   24.0   9.0
#              1                  48.0           48.0  24.0  12.0   24.0   NaN
#              2                  48.0           48.0  24.0  12.0   24.0   NaN
#
#                         ...                                                \
#                         ...   window_size
# method                  ... OBKNN (TNone) OBKNN (TZnorm)  OIF RRCF RSHash
# cod_scenario iteration  ...
# 116          0          ...           3.0            3.0  3.0  3.0    3.0
#              1          ...           3.0            3.0  3.0  3.0    3.0
#              2          ...           3.0            3.0  3.0  3.0    3.0
# DA3          0          ...           3.0            3.0  3.0  3.0    3.0
#              1          ...           3.0            3.0  3.0  3.0    3.0
#              2          ...           3.0            3.0  3.0  3.0    3.0
#
#
#
# method                 SWKNN SWLOF XStream mDragStream (Euc) mDragStream (Mah)
# cod_scenario iteration
# 116          0           3.0   3.0     3.0               3.0               3.0
#              1           NaN   NaN     3.0               NaN               NaN
#              2           NaN   NaN     3.0               NaN               NaN
# DA3          0           3.0   3.0     3.0               3.0               3.0
#              1           NaN   NaN     3.0               NaN               NaN
#              2           NaN   NaN     3.0               NaN               NaN
#
# [6 rows x 28 columns]

# %%
params_obknn = filtered_data[filtered_data['method']=="OBKNN"][TYPE_WS].unique()
len(params_obknn)
# Out:
# 0

# %%
params_obknn
# Out:
# array([], dtype=object)

# %%
# Obtaining the best hyperparameters
# 1. average results over all iterations and all scenarios
averaged_results = filtered_data.groupby(['method', TYPE_WS, 'cod_scenario'])['raw_pr_auc'].agg(
    mean_auc_pr='mean',
    std_auc_pr='std',
    n_runs='count'
).reset_index()

# 2. average results for each method and hyperparameter for all scenarios
summary = averaged_results.groupby(['method', TYPE_WS]).agg(
    mean_auc_pr=('mean_auc_pr', 'mean'),
    beetween_std_auc_pr=('mean_auc_pr', 'std'),
    within_std_auc_pr=('std_auc_pr', 'mean'),
    n_scenarios=('mean_auc_pr', 'count'),
    n_experiments=('n_runs', 'sum')
).reset_index()


#summary.sort_values(['mean_auc_pr','std_auc_pr'], ascending=[False, True]).head(10)

# Obtaining the best hyperparameters 
# 3. Select the highest AUC_PR per method and hyperparameter with lowest standard deviation beetween scenarios
best_results = (
    summary
    .sort_values(['mean_auc_pr','beetween_std_auc_pr'], ascending=[False, True])
    .groupby('method')
    .head(1)
)
best_params = best_results[TYPE_WS].unique().tolist()
best_results
# Out:
#                 method  \
# 102      OBKNN (TNone)
# 41               IFASD
# 54              KitNet
# 223              SWKNN
# 185                OIF
# 14              EStorm
# 153     OBKNN (TZnorm)
# 287  mDragStream (Mah)
# 275  mDragStream (Euc)
# 20              HStree
# 248            XStream
# 234              SWLOF
# 196               RRCF
# 220             RSHash
#
#                                                                                                                                                                                                                                                                                                              params_with_p_window_size  \
# 102      {'p_window_size': 0.2, 'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}
# 41                                                                                                                                                                                                                                                                                    {'p_window_size': 0.2, 'initial_window_X': None}
# 54                                                                                                                                                                                                                                               {'p_window_size': 0.05, 'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}
# 223                                                                                                                                                                                           {'p_window_size': 0.02, 'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}
# 185                                                                                                                                                                                                                         {'p_window_size': 0.2, 'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}
# 14                                                                                                                                                                                                                                                                                           {'p_window_size': 0.2, 'max_radius': 900}
# 153  {'p_window_size': 0.2, 'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}
# 287                                                                                                                                                                                                                        {'p_window_size': 0.2, 'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}
# 275                                                                                                                                                                                                                          {'p_window_size': 0.2, 'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}
# 20                                                                                                                                                                                                                        {'p_window_size': 0.02, 'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}
# 248                                                                                                                                                                                                                                                        {'p_window_size': 0.02, 'depth': 25, 'n_chains': 100, 'num_components': 50}
# 234                                                                                                                                                                                                                                    {'p_window_size': 0.02, 'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}
# 196                                                                                                                                                                                                                                                                           {'p_window_size': 0.2, 'num_trees': 4, 'tree_size': 256}
# 220                                                                                                                                                                                                  {'p_window_size': 0.2, 'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}
#
#      mean_auc_pr  beetween_std_auc_pr  within_std_auc_pr  n_scenarios  \
# 102     0.967986             0.043575           0.003943            2
# 41      0.959322             0.044329           0.003482            2
# 54      0.943090             0.032492                NaN            2
# 223     0.936771             0.089419                NaN            2
# 185     0.648609             0.496942           0.020312            2
# 14      0.557143             0.045457                NaN            2
# 153     0.548261             0.625520           0.000421            2
# 287     0.516242             0.681667                NaN            2
# 275     0.481743             0.628005                NaN            2
# 20      0.480364             0.644116           0.007364            2
# 248     0.457042             0.083369           0.021800            2
# 234     0.362281             0.268258                NaN            2
# 196     0.283424             0.118278           0.042107            2
# 220     0.084620             0.083636           0.000057            2
#
#      n_experiments
# 102              6
# 41               6
# 54               2
# 223              2
# 185              6
# 14               2
# 153              6
# 287              2
# 275              2
# 20               6
# 248              6
# 234              2
# 196              6
# 220              6

# %% [markdown]
# ## Summary Score of Online Anomaly Detectors with PV Datasets

# %%
# Filtering just the best hyperparameters
filtered_data = filtered_data[filtered_data[TYPE_WS].isin(best_params)]
#filtered_data = filtered_data[filtered_data["method"].isin(["OBKNN (TNone)", "OBKNN (TZnorm)"])]
#filtered_data = filtered_data[filtered_data["method"].isin(["HStree"])]
filtered_data.params_with_p_window_size.unique()
# Out:
# array(["{'p_window_size': 0.02, 'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}",
#        "{'p_window_size': 0.2, 'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}",
#        "{'p_window_size': 0.2, 'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}",
#        "{'p_window_size': 0.2, 'initial_window_X': None}",
#        "{'p_window_size': 0.02, 'depth': 25, 'n_chains': 100, 'num_components': 50}",
#        "{'p_window_size': 0.02, 'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}",
#        "{'p_window_size': 0.02, 'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}",
#        "{'p_window_size': 0.2, 'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}",
#        "{'p_window_size': 0.2, 'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}",
#        "{'p_window_size': 0.2, 'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}",
#        "{'p_window_size': 0.2, 'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}",
#        "{'p_window_size': 0.2, 'num_trees': 4, 'tree_size': 256}",
#        "{'p_window_size': 0.2, 'max_radius': 900}",
#        "{'p_window_size': 0.05, 'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}"],
#       dtype=object)

# %%
# Pivot for mean - includes all data
mean_pivot = filtered_data.pivot_table(
    values="raw_pr_auc",
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="mean"
)

# Pivot for std - includes all data
# Note: This will be NaN for all 'N' rows, which is correct.
std_pivot = filtered_data.pivot_table(
    values="raw_pr_auc",
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="std"
)


# 2. Stack the DataFrames to align them as Series
mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
std_s = std_pivot.stack(level=[0, 1], dropna=False)

# 3. Apply the formatting function row-by-row
combined_s = pd.DataFrame({'mean': mean_s, 'std': std_s}).apply(
    lambda row: format_mean_std(row['mean'], row['std']), 
    axis=1
)

# 4. Unstack back into a DataFrame
combined = combined_s.unstack(level=[-2, -1])
# Ensure column order is the same as the original pivot
if not combined.empty:
    combined = combined.reindex(columns=mean_pivot.columns)
else:
    # Handle case where combined might be empty
    combined = pd.DataFrame(index=mean_pivot.index, columns=mean_pivot.columns)


# Get the numeric averages first (for sorting and formatting)
avg_mean = mean_pivot.mean(axis=1)
avg_std = std_pivot.mean(axis=1) # This will be NaN for 'N' rows

# 5. Apply the same formatting logic to the Avg column
avg_col_s = pd.DataFrame({'mean': avg_mean, 'std': avg_std}).apply(
    lambda row: format_mean_std(row['mean'], row['std']),
    axis=1
)

combined["Avg"] = avg_col_s

# 6. Sort by the *numeric* average mean (before it was a string)
combined = combined.loc[avg_mean.sort_values(ascending=False).index]

# 7. Display with HTML formatting in Jupyter
combined
# Out:
# /tmp/ipykernel_570305/197214830.py:20: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
# /tmp/ipykernel_570305/197214830.py:21: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   std_s = std_pivot.stack(level=[0, 1], dropna=False)
# cod_scenario                                                                                                                                                                                                                                                                                                                                      116  \
# window_size                                                                                                                                                                                                                                                                                                                                       200
# method_and_year          parameters
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}                  NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                               NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 1.000 ± NA
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                     NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                      NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}              NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                                    NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                      NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.025 ± 2.9e-06
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.516 ± 2.0e-02
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.552 ± NA
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                       NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                              NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                      2000
# method_and_year          parameters
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.937 ± 7.9e-03
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.991 ± 4.9e-03
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                        NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         1.000 ± 0.0e+00
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               0.525 ± NA
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.991 ± 5.8e-04
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.034 ± NA
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.038 ± NA
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                                    NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                     NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                                 NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.367 ± 5.7e-02
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  0.025 ± 7.3e-06
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                      \
# window_size                                                                                                                                                                                                                                                                                                                                  500
# method_and_year          parameters
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}             NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                          NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                               0.966 ± NA
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                   NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                 NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}         NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                               NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                 NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                               NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                            NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                  NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                         NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                 DA3  \
# window_size                                                                                                                                                                                                                                                                                                                                  210
# method_and_year          parameters
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}             NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                          NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                               0.920 ± NA
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                   NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                 NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}         NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                               NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                 NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                               NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                            NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                  NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                         NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                        84
# method_and_year          parameters
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}                  NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                               NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.874 ± NA
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                     NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                      NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}              NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                                    NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                      NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.936 ± 1.5e-02
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.398 ± 2.4e-02
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.173 ± NA
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                       NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                              NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                       840
# method_and_year          parameters
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.999 ± 1.1e-05
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.928 ± 2.1e-03
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                        NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.297 ± 4.1e-02
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               0.589 ± NA
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.106 ± 2.6e-04
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.998 ± NA
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.926 ± NA
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                                    NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                     NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                                 NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.200 ± 2.7e-02
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  0.144 ± 1.1e-04
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                      Avg
# window_size
# method_and_year          parameters
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.968 ± 3.9e-03
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.959 ± 3.5e-03
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                    0.943 ± NA
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.937 ± NA
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.649 ± 2.0e-02
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               0.557 ± NA
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.548 ± 4.2e-04
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.516 ± NA
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.482 ± NA
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.480 ± 7.4e-03
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.457 ± 2.2e-02
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.362 ± NA
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.283 ± 4.2e-02
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  0.085 ± 5.7e-05

# %%
# Generate the report and the plot
# 'alpha' is the significance level
# 'verbose=False' suppresses console output of the report
# 'order='descending' because higher accuracy is better
mean_pivot = filtered_data.pivot_table(
    values="raw_pr_auc",
    index="cod_scenario",
    columns=["method"],
    aggfunc="mean"
)

#result = autorank(mean_pivot, alpha=0.05, verbose=False, order='descending')
#print(result)

#create_report(result)


#plot_stats(result, allow_insignificant=False)
#plt.savefig(current_dir / 'notebooks' / 'img_cdd'/ "cdd_all_methods.pdf", format="pdf", dpi=300, bbox_inches='tight')

plt.show()

# %%
# Pivot for mean - includes all data
mean_pivot = filtered_data.pivot_table(
    values="raw_pr_auc_wtd",
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="mean"
)

# Pivot for std - includes all data
# Note: This will be NaN for all 'N' rows, which is correct.
std_pivot = filtered_data.pivot_table(
    values="raw_pr_auc_wtd",
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="std"
)


# 2. Stack the DataFrames to align them as Series
mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
std_s = std_pivot.stack(level=[0, 1], dropna=False)

# 3. Apply the formatting function row-by-row
combined_s = pd.DataFrame({'mean': mean_s, 'std': std_s}).apply(
    lambda row: format_mean_std(row['mean'], row['std']), 
    axis=1
)

# 4. Unstack back into a DataFrame
combined = combined_s.unstack(level=[-2, -1])
# Ensure column order is the same as the original pivot
if not combined.empty:
    combined = combined.reindex(columns=mean_pivot.columns)
else:
    # Handle case where combined might be empty
    combined = pd.DataFrame(index=mean_pivot.index, columns=mean_pivot.columns)


# Get the numeric averages first (for sorting and formatting)
avg_mean = mean_pivot.mean(axis=1)
avg_std = std_pivot.mean(axis=1) # This will be NaN for 'N' rows

# 5. Apply the same formatting logic to the Avg column
avg_col_s = pd.DataFrame({'mean': avg_mean, 'std': avg_std}).apply(
    lambda row: format_mean_std(row['mean'], row['std']),
    axis=1
)

combined["Avg"] = avg_col_s

# 6. Sort by the *numeric* average mean (before it was a string)
combined = combined.loc[avg_mean.sort_values(ascending=False).index]

# 7. Display with HTML formatting in Jupyter
combined
# Out:
# /tmp/ipykernel_570305/1280918794.py:20: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
# /tmp/ipykernel_570305/1280918794.py:21: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   std_s = std_pivot.stack(level=[0, 1], dropna=False)
# cod_scenario                                                                                                                                                                                                                                                                                                                                      116  \
# window_size                                                                                                                                                                                                                                                                                                                                       200
# method_and_year          parameters
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                               NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}                  NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.925 ± NA
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                      NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}              NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                     NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.513 ± 1.9e-02
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.025 ± 2.7e-06
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.557 ± NA
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                       NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                                    NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                      NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                              NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                      2000
# method_and_year          parameters
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.985 ± 4.3e-03
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.773 ± 6.6e-03
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                        NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               0.525 ± NA
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.910 ± 1.7e-04
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.725 ± 2.3e-04
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                     NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                                    NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                                 NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.372 ± 5.6e-02
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.122 ± NA
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.125 ± NA
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  0.025 ± 5.7e-06
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                      \
# window_size                                                                                                                                                                                                                                                                                                                                  500
# method_and_year          parameters
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                          NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                               0.918 ± NA
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}             NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                   NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                 NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}         NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                               NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                            NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                  NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                               NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                 NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                         NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                 DA3  \
# window_size                                                                                                                                                                                                                                                                                                                                  210
# method_and_year          parameters
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                          NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                               0.920 ± NA
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}             NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                   NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                 NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}         NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                               NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                            NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                  NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                               NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                 NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                         NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                        84
# method_and_year          parameters
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                               NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}                  NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.823 ± NA
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                      NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}              NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                     NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.363 ± 2.2e-02
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.725 ± 1.4e-02
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.171 ± NA
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                       NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                                    NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                      NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                              NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                       840
# method_and_year          parameters
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.923 ± 1.7e-03
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.999 ± 1.1e-05
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                        NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               0.571 ± NA
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.082 ± 2.5e-04
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.245 ± 2.6e-02
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                     NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                                    NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                                 NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.166 ± 2.2e-02
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.245 ± NA
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.228 ± NA
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  0.127 ± 8.4e-05
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                      Avg
# window_size
# method_and_year          parameters
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.954 ± 3.0e-03
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                    0.919 ± NA
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.886 ± 3.3e-03
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.874 ± NA
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               0.548 ± NA
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.496 ± 2.1e-04
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.485 ± 1.3e-02
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.438 ± 2.0e-02
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.375 ± 6.8e-03
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.364 ± NA
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.269 ± 3.9e-02
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.184 ± NA
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.177 ± NA
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  0.076 ± 4.5e-05

# %%
# Pivot for mean - includes all data
mean_pivot = filtered_data.pivot_table(
    values="vus_pr",
    columns=["cod_scenario","window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="mean"
)

# Pivot for std - includes all data
# Note: This will be NaN for all 'N' rows, which is correct.
std_pivot = filtered_data.pivot_table(
    values="vus_pr",
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="std"
)


# 2. Stack the DataFrames to align them as Series
mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
std_s = std_pivot.stack(level=[0, 1], dropna=False)

# 3. Apply the formatting function row-by-row
combined_s = pd.DataFrame({'mean': mean_s, 'std': std_s}).apply(
    lambda row: format_mean_std(row['mean'], row['std']), 
    axis=1
)

# 4. Unstack back into a DataFrame
combined = combined_s.unstack(level=[-2, -1])
# Ensure column order is the same as the original pivot
if not combined.empty:
    combined = combined.reindex(columns=mean_pivot.columns)
else:
    # Handle case where combined might be empty
    combined = pd.DataFrame(index=mean_pivot.index, columns=mean_pivot.columns)


# Get the numeric averages first (for sorting and formatting)
avg_mean = mean_pivot.mean(axis=1)
avg_std = std_pivot.mean(axis=1) # This will be NaN for 'N' rows

# 5. Apply the same formatting logic to the Avg column
avg_col_s = pd.DataFrame({'mean': avg_mean, 'std': avg_std}).apply(
    lambda row: format_mean_std(row['mean'], row['std']),
    axis=1
)

combined["Avg"] = avg_col_s

# 6. Sort by the *numeric* average mean (before it was a string)
combined = combined.loc[avg_mean.sort_values(ascending=False).index]

# 7. Display with HTML formatting in Jupyter
combined
# Out:
# /tmp/ipykernel_570305/3280624656.py:20: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
# /tmp/ipykernel_570305/3280624656.py:21: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   std_s = std_pivot.stack(level=[0, 1], dropna=False)
# cod_scenario                                                                                                                                                                                                                                                                                                                                      116  \
# window_size                                                                                                                                                                                                                                                                                                                                       200
# method_and_year          parameters
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                               NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.999 ± NA
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}                  NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                     NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}              NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.568 ± 3.9e-02
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                                    NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                      NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.035 ± 1.1e-05
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                       NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.318 ± NA
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                      NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                              NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                      2000
# method_and_year          parameters
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.987 ± 5.3e-03
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                        NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.873 ± 1.5e-02
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.997 ± 1.1e-04
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.987 ± 1.1e-03
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                     NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.049 ± NA
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.048 ± NA
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                                    NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.383 ± 5.5e-02
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                                 NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               0.050 ± NA
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  0.036 ± 9.5e-06
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                      \
# window_size                                                                                                                                                                                                                                                                                                                                  500
# method_and_year          parameters
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                          NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                               0.990 ± NA
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                   NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}             NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}         NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                               NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                 NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                               NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                  NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                            NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                 NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                         NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                 DA3  \
# window_size                                                                                                                                                                                                                                                                                                                                  210
# method_and_year          parameters
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                          NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                               0.935 ± NA
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                   NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}             NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}         NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                               NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                 NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                               NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                  NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                            NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                 NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                         NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                        84
# method_and_year          parameters
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                               NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.923 ± NA
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}                  NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                     NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}              NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.537 ± 2.1e-02
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                                    NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                      NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.977 ± 6.4e-03
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                       NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.257 ± NA
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                      NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                              NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                       840
# method_and_year          parameters
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.976 ± 8.2e-04
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                        NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      1.000 ± 3.7e-07
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.423 ± 4.3e-02
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.132 ± 3.5e-05
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                     NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             1.000 ± NA
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.974 ± NA
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                                    NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.275 ± 2.1e-02
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                                 NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               0.255 ± NA
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  0.199 ± 1.6e-04
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                      Avg
# window_size
# method_and_year          parameters
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.982 ± 3.1e-03
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                    0.962 ± NA
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.961 ± NA
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.937 ± 7.6e-03
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.710 ± 2.2e-02
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.559 ± 5.9e-04
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.553 ± 3.0e-02
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.525 ± NA
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.511 ± NA
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.506 ± 3.2e-03
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.329 ± 3.8e-02
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.288 ± NA
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               0.153 ± NA
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  0.117 ± 8.3e-05

# %%
# Generate the report and the plot
# 'alpha' is the significance level
# 'verbose=False' suppresses console output of the report
# 'order='descending' because higher accuracy is better
mean_pivot = filtered_data.pivot_table(
    values="vus_pr",
    index="cod_scenario",
    columns=["method"],
    aggfunc="mean"
)

#result = autorank(mean_pivot, alpha=0.05, verbose=False, order='descending')
#print(result)

#create_report(result)


#plot_stats(result, allow_insignificant=False)
#plt.savefig(current_dir / 'notebooks' / 'img_cdd'/ "cdd_all_methods.pdf", format="pdf", dpi=300, bbox_inches='tight')

plt.show()

# %%
# Pivot for mean - includes all data
mean_pivot = filtered_data.pivot_table(
    values="auc_roc",
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="mean"
)

# Pivot for std - includes all data
# Note: This will be NaN for all 'N' rows, which is correct.
std_pivot = filtered_data.pivot_table(
    values="auc_roc",
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="std"
)


# 2. Stack the DataFrames to align them as Series
mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
std_s = std_pivot.stack(level=[0, 1], dropna=False)

# 3. Apply the formatting function row-by-row
combined_s = pd.DataFrame({'mean': mean_s, 'std': std_s}).apply(
    lambda row: format_mean_std(row['mean'], row['std']), 
    axis=1
)

# 4. Unstack back into a DataFrame
combined = combined_s.unstack(level=[-2, -1])
# Ensure column order is the same as the original pivot
if not combined.empty:
    combined = combined.reindex(columns=mean_pivot.columns)
else:
    # Handle case where combined might be empty
    combined = pd.DataFrame(index=mean_pivot.index, columns=mean_pivot.columns)


# Get the numeric averages first (for sorting and formatting)
avg_mean = mean_pivot.mean(axis=1)
avg_std = std_pivot.mean(axis=1) # This will be NaN for 'N' rows

# 5. Apply the same formatting logic to the Avg column
avg_col_s = pd.DataFrame({'mean': avg_mean, 'std': avg_std}).apply(
    lambda row: format_mean_std(row['mean'], row['std']),
    axis=1
)

combined["Avg"] = avg_col_s

# 6. Sort by the *numeric* average mean (before it was a string)
combined = combined.loc[avg_mean.sort_values(ascending=False).index]

# 7. Display with HTML formatting in Jupyter
combined
# Out:
# /tmp/ipykernel_570305/3052700536.py:20: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
# /tmp/ipykernel_570305/3052700536.py:21: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   std_s = std_pivot.stack(level=[0, 1], dropna=False)
# cod_scenario                                                                                                                                                                                                                                                                                                                                      116  \
# window_size                                                                                                                                                                                                                                                                                                                                       200
# method_and_year          parameters
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 1.000 ± NA
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}                  NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                               NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.969 ± 1.3e-02
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                     NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                       NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.657 ± NA
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}              NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                      NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                                    NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                      NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.000 ± 1.2e-04
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                              NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                      2000
# method_and_year          parameters
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                        NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.975 ± 5.9e-03
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   1.000 ± 1.7e-04
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                     NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         1.000 ± 0.0e+00
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.956 ± 1.1e-02
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                                 NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.997 ± 2.4e-05
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.156 ± NA
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.016 ± NA
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               0.500 ± NA
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                                    NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  0.003 ± 3.4e-04
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                      \
# window_size                                                                                                                                                                                                                                                                                                                                  500
# method_and_year          parameters
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                   NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                               1.000 ± NA
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}             NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                          NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                  NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                            NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}         NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                 NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                               NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                 NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                               NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                         NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                 DA3  \
# window_size                                                                                                                                                                                                                                                                                                                                  210
# method_and_year          parameters
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                   NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                               0.985 ± NA
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}             NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                          NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                  NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                            NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}         NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                 NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                               NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                 NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                               NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                         NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                        84
# method_and_year          parameters
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.991 ± NA
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}                  NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                               NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.856 ± 1.0e-02
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                     NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                       NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.516 ± NA
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}              NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                      NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                                    NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                      NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.975 ± 1.3e-02
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                              NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                       840
# method_and_year          parameters
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                        NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      1.000 ± 3.5e-06
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.947 ± 4.2e-03
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                     NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.699 ± 3.9e-02
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.494 ± 5.1e-02
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                                 NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.130 ± 2.3e-04
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.945 ± NA
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.999 ± NA
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               0.500 ± NA
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                                    NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  0.405 ± 4.2e-04
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                      Avg
# window_size
# method_and_year          parameters
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.996 ± NA
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                    0.992 ± NA
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.987 ± 2.9e-03
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.973 ± 2.2e-03
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.913 ± 1.2e-02
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.850 ± 2.0e-02
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.725 ± 3.1e-02
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.586 ± NA
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.564 ± 1.3e-04
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.550 ± NA
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.508 ± NA
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               0.500 ± NA
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.488 ± 6.6e-03
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  0.204 ± 3.8e-04

# %%
# Pivot for mean - includes all data
mean_pivot = filtered_data.pivot_table(
    values="raw_pct_detection", # raw_pct_false_positives ,  raw_pct_detection, raw_max_f1
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="mean"
)

# Pivot for std - includes all data
# Note: This will be NaN for all 'N' rows, which is correct.
std_pivot = filtered_data.pivot_table(
    values="raw_pct_detection", # raw_pct_false_positives ,  raw_pct_detection, raw_max_f1
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="std"
)


# 2. Stack the DataFrames to align them as Series
mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
std_s = std_pivot.stack(level=[0, 1], dropna=False)

# 3. Apply the formatting function row-by-row
combined_s = pd.DataFrame({'mean': mean_s, 'std': std_s}).apply(
    lambda row: format_mean_std(row['mean'], row['std']), 
    axis=1
)

# 4. Unstack back into a DataFrame
combined = combined_s.unstack(level=[-2, -1])
# Ensure column order is the same as the original pivot
if not combined.empty:
    combined = combined.reindex(columns=mean_pivot.columns)
else:
    # Handle case where combined might be empty
    combined = pd.DataFrame(index=mean_pivot.index, columns=mean_pivot.columns)


# Get the numeric averages first (for sorting and formatting)
avg_mean = mean_pivot.mean(axis=1)
avg_std = std_pivot.mean(axis=1) # This will be NaN for 'N' rows

# 5. Apply the same formatting logic to the Avg column
avg_col_s = pd.DataFrame({'mean': avg_mean, 'std': avg_std}).apply(
    lambda row: format_mean_std(row['mean'], row['std']),
    axis=1
)

combined["Avg"] = avg_col_s

# 6. Sort by the *numeric* average mean (before it was a string)
combined = combined.loc[avg_mean.sort_values(ascending=False).index]

# 7. Display with HTML formatting in Jupyter
combined
# Out:
# /tmp/ipykernel_570305/2610500056.py:20: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
# /tmp/ipykernel_570305/2610500056.py:21: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   std_s = std_pivot.stack(level=[0, 1], dropna=False)
# cod_scenario                                                                                                                                                                                                                                                                                                                                      116  \
# window_size                                                                                                                                                                                                                                                                                                                                       200
# method_and_year          parameters
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                      NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                              NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 1.000 ± NA
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                                    NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}              NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}                  NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                               NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                      NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.937 ± 4.6e-02
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                       NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        1.000 ± 0.0e+00
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                     NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.525 ± NA
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                      2000
# method_and_year          parameters
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               1.000 ± NA
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  1.000 ± 0.0e+00
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                        NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             1.000 ± NA
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.995 ± 0.0e+00
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.922 ± 9.5e-03
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   1.000 ± 0.0e+00
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               1.000 ± NA
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                     NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.860 ± 4.5e-02
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                                    NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         1.000 ± 0.0e+00
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                                 NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                      \
# window_size                                                                                                                                                                                                                                                                                                                                  500
# method_and_year          parameters
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                 NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                               1.000 ± NA
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                         NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                   NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                               NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}         NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}             NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                          NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                 NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                  NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                               NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                            NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                 DA3  \
# window_size                                                                                                                                                                                                                                                                                                                                  210
# method_and_year          parameters
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                 NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                               1.000 ± NA
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                         NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                   NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                               NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}         NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}             NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                          NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                 NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                  NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                               NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                            NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                        84
# method_and_year          parameters
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                      NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                              NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.998 ± NA
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                                    NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}              NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}                  NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                               NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                      NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.934 ± 1.2e-02
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                       NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.847 ± 2.4e-02
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                     NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.867 ± NA
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                       840
# method_and_year          parameters
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               1.000 ± NA
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  1.000 ± 0.0e+00
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                        NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.998 ± NA
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  1.000 ± 0.0e+00
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.998 ± 0.0e+00
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.897 ± 0.0e+00
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.888 ± NA
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                     NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.999 ± 9.6e-04
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                                    NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.826 ± 2.0e-02
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                                 NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                      Avg
# window_size
# method_and_year          parameters
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               1.000 ± NA
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                    1.000 ± NA
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  1.000 ± 0.0e+00
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.999 ± NA
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.999 ± NA
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.998 ± 0.0e+00
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.960 ± 4.7e-03
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.948 ± 0.0e+00
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.944 ± NA
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.936 ± 2.9e-02
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.930 ± 2.3e-02
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.924 ± 1.2e-02
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.913 ± 1.0e-02
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.696 ± NA

# %%
# Pivot for mean - includes all data
mean_pivot = filtered_data.pivot_table(
    values="raw_pct_false_positives", # raw_pct_false_positives ,  raw_pct_detection, raw_max_f1
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="mean"
)

# Pivot for std - includes all data
# Note: This will be NaN for all 'N' rows, which is correct.
std_pivot = filtered_data.pivot_table(
    values="raw_pct_false_positives", # raw_pct_false_positives ,  raw_pct_detection, raw_max_f1
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="std"
)


# 2. Stack the DataFrames to align them as Series
mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
std_s = std_pivot.stack(level=[0, 1], dropna=False)

# 3. Apply the formatting function row-by-row
combined_s = pd.DataFrame({'mean': mean_s, 'std': std_s}).apply(
    lambda row: format_mean_std(row['mean'], row['std']), 
    axis=1
)

# 4. Unstack back into a DataFrame
combined = combined_s.unstack(level=[-2, -1])
# Ensure column order is the same as the original pivot
if not combined.empty:
    combined = combined.reindex(columns=mean_pivot.columns)
else:
    # Handle case where combined might be empty
    combined = pd.DataFrame(index=mean_pivot.index, columns=mean_pivot.columns)


# Get the numeric averages first (for sorting and formatting)
avg_mean = mean_pivot.mean(axis=1)
avg_std = std_pivot.mean(axis=1) # This will be NaN for 'N' rows

# 5. Apply the same formatting logic to the Avg column
avg_col_s = pd.DataFrame({'mean': avg_mean, 'std': avg_std}).apply(
    lambda row: format_mean_std(row['mean'], row['std']),
    axis=1
)

combined["Avg"] = avg_col_s

# 6. Sort by the *numeric* average mean (before it was a string)
combined = combined.loc[avg_mean.sort_values(ascending=False).index]

# 7. Display with HTML formatting in Jupyter
combined
# Out:
# /tmp/ipykernel_570305/2505021859.py:20: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
# /tmp/ipykernel_570305/2505021859.py:21: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   std_s = std_pivot.stack(level=[0, 1], dropna=False)
# cod_scenario                                                                                                                                                                                                                                                                                                                                      116  \
# window_size                                                                                                                                                                                                                                                                                                                                       200
# method_and_year          parameters
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                      NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                              NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                       NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        1.000 ± 0.0e+00
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                      NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                                    NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}              NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.001 ± NA
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                     NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.022 ± 3.2e-04
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.000 ± NA
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                               NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}                  NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                      2000
# method_and_year          parameters
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               1.000 ± NA
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  1.000 ± 7.6e-05
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.071 ± 1.7e-02
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                                    NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               1.000 ± NA
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             1.000 ± NA
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.000 ± 2.0e-04
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                                 NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.000 ± 0.0e+00
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                     NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                        NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.002 ± 8.5e-04
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.000 ± 0.0e+00
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                      \
# window_size                                                                                                                                                                                                                                                                                                                                  500
# method_and_year          parameters
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                 NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                         NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                  NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                               NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                 NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                               NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}         NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                            NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                               0.001 ± NA
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                   NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                          NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}             NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                 DA3  \
# window_size                                                                                                                                                                                                                                                                                                                                  210
# method_and_year          parameters
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                 NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                         NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                  NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                               NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                 NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                               NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}         NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                            NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                               0.068 ± NA
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                   NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                          NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}             NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                        84
# method_and_year          parameters
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                      NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                              NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                       NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.016 ± 4.6e-03
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                      NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                                    NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}              NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.815 ± NA
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                     NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.263 ± 2.8e-02
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.009 ± NA
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                               NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}                  NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                       840
# method_and_year          parameters
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               1.000 ± NA
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  1.000 ± 0.0e+00
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.996 ± 1.9e-03
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                                    NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.006 ± NA
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.001 ± NA
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.994 ± 3.6e-04
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                                 NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.472 ± 6.0e-02
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                     NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                        NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.000 ± 0.0e+00
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.000 ± 0.0e+00
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                      Avg
# window_size
# method_and_year          parameters
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               1.000 ± NA
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  1.000 ± 3.8e-05
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.534 ± 9.4e-03
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.508 ± 2.3e-03
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.503 ± NA
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.500 ± NA
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.497 ± 2.8e-04
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.408 ± NA
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.236 ± 3.0e-02
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.143 ± 1.4e-02
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                    0.035 ± NA
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.005 ± NA
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.001 ± 4.2e-04
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.000 ± 0.0e+00

# %%
# Pivot for mean - includes all data
mean_pivot = filtered_data.pivot_table(
    values="raw_max_f1", # raw_pct_false_positives ,  raw_pct_detection, raw_max_f1
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="mean"
)

# Pivot for std - includes all data
# Note: This will be NaN for all 'N' rows, which is correct.
std_pivot = filtered_data.pivot_table(
    values="raw_max_f1", # raw_pct_false_positives ,  raw_pct_detection, raw_max_f1
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="std"
)


# 2. Stack the DataFrames to align them as Series
mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
std_s = std_pivot.stack(level=[0, 1], dropna=False)

# 3. Apply the formatting function row-by-row
combined_s = pd.DataFrame({'mean': mean_s, 'std': std_s}).apply(
    lambda row: format_mean_std(row['mean'], row['std']), 
    axis=1
)

# 4. Unstack back into a DataFrame
combined = combined_s.unstack(level=[-2, -1])
# Ensure column order is the same as the original pivot
if not combined.empty:
    combined = combined.reindex(columns=mean_pivot.columns)
else:
    # Handle case where combined might be empty
    combined = pd.DataFrame(index=mean_pivot.index, columns=mean_pivot.columns)


# Get the numeric averages first (for sorting and formatting)
avg_mean = mean_pivot.mean(axis=1)
avg_std = std_pivot.mean(axis=1) # This will be NaN for 'N' rows

# 5. Apply the same formatting logic to the Avg column
avg_col_s = pd.DataFrame({'mean': avg_mean, 'std': avg_std}).apply(
    lambda row: format_mean_std(row['mean'], row['std']),
    axis=1
)

combined["Avg"] = avg_col_s

# 6. Sort by the *numeric* average mean (before it was a string)
combined = combined.loc[avg_mean.sort_values(ascending=False).index]

# 7. Display with HTML formatting in Jupyter
combined
# Out:
# /tmp/ipykernel_570305/425158449.py:20: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
# /tmp/ipykernel_570305/425158449.py:21: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   std_s = std_pivot.stack(level=[0, 1], dropna=False)
# cod_scenario                                                                                                                                                                                                                                                                                                                                      116  \
# window_size                                                                                                                                                                                                                                                                                                                                       200
# method_and_year          parameters
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 1.000 ± NA
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}                  NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                               NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                     NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.791 ± 2.3e-02
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}              NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                                    NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                      NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.093 ± 0.0e+00
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.681 ± NA
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                       NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                              NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                      NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                      2000
# method_and_year          parameters
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                        NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.959 ± 5.1e-03
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.986 ± 7.8e-03
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         1.000 ± 0.0e+00
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                     NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.993 ± 1.9e-03
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.095 ± NA
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.095 ± NA
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                                    NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                                 NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.539 ± 4.8e-02
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  0.095 ± 6.6e-06
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               0.095 ± NA
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                      \
# window_size                                                                                                                                                                                                                                                                                                                                  500
# method_and_year          parameters
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                   NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}             NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                          NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                               0.994 ± NA
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}         NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                               NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                 NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                               NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                            NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                  NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                         NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                 NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                 DA3  \
# window_size                                                                                                                                                                                                                                                                                                                                  210
# method_and_year          parameters
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                   NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}             NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                          NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                               0.838 ± NA
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}         NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                               NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                 NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                               NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                            NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                  NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                         NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                 NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                        84
# method_and_year          parameters
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.973 ± NA
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}                  NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                               NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                     NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.538 ± 2.3e-02
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}              NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                                    NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                      NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.873 ± 2.0e-03
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.261 ± NA
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                       NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                              NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                      NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                       840
# method_and_year          parameters
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                        NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.998 ± 0.0e+00
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.946 ± 0.0e+00
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.414 ± 2.4e-02
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                     NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.304 ± 7.7e-05
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.998 ± NA
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.928 ± NA
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                                    NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                                 NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.304 ± 4.2e-04
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  0.303 ± 0.0e+00
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               0.303 ± NA
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                      Avg
# window_size
# method_and_year          parameters
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.987 ± NA
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.979 ± 2.6e-03
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.966 ± 3.9e-03
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                    0.916 ± NA
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.707 ± 1.2e-02
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.664 ± 2.3e-02
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.649 ± 9.9e-04
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.546 ± NA
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.512 ± NA
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.483 ± 1.0e-03
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.471 ± NA
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.421 ± 2.4e-02
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  0.199 ± 3.3e-06
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               0.199 ± NA

# %% [markdown]
# ## Summary Training Time of Online Anomaly Detectors with PV Datasets

# %%
# Pivot for mean - includes all data
mean_pivot = filtered_data.pivot_table(
    values="mean_training_time",
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="mean"
)

# Pivot for std - includes all data
# Note: This will be NaN for all 'N' rows, which is correct.
std_pivot = filtered_data.pivot_table(
    values="mean_training_time",
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="std"
)


# 2. Stack the DataFrames to align them as Series
mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
std_s = std_pivot.stack(level=[0, 1], dropna=False)

# 3. Apply the formatting function row-by-row
combined_s = pd.DataFrame({'mean': mean_s, 'std': std_s}).apply(
    lambda row: format_mean_std(row['mean'], row['std']), 
    axis=1
)

# 4. Unstack back into a DataFrame
combined = combined_s.unstack(level=[-2, -1])
# Ensure column order is the same as the original pivot
if not combined.empty:
    combined = combined.reindex(columns=mean_pivot.columns)
else:
    # Handle case where combined might be empty
    combined = pd.DataFrame(index=mean_pivot.index, columns=mean_pivot.columns)


# Get the numeric averages first (for sorting and formatting)
avg_mean = mean_pivot.mean(axis=1)
avg_std = std_pivot.mean(axis=1) # This will be NaN for 'N' rows

# 5. Apply the same formatting logic to the Avg column
avg_col_s = pd.DataFrame({'mean': avg_mean, 'std': avg_std}).apply(
    lambda row: format_mean_std(row['mean'], row['std']),
    axis=1
)

combined["Avg"] = avg_col_s

# 6. Sort by the *numeric* average mean (before it was a string)
combined = combined.loc[avg_mean.sort_values(ascending=False).index]

# 7. Display with HTML formatting in Jupyter
combined
# Out:
# /tmp/ipykernel_570305/1826925235.py:20: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
# /tmp/ipykernel_570305/1826925235.py:21: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   std_s = std_pivot.stack(level=[0, 1], dropna=False)
# cod_scenario                                                                                                                                                                                                                                                                                                                                      116  \
# window_size                                                                                                                                                                                                                                                                                                                                       200
# method_and_year          parameters
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                                    NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                     NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.044 ± 2.7e-05
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                               NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}              NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}                  NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                       NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                              NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                      NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                      NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.000 ± 2.2e-08
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.000 ± NA
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.000 ± NA
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                      2000
# method_and_year          parameters
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.002 ± NA
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.072 ± 1.9e-03
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                     NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.035 ± 2.6e-05
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.007 ± 2.1e-05
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.007 ± 6.0e-06
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.002 ± 3.2e-05
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  0.003 ± 1.3e-05
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.001 ± NA
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               0.000 ± NA
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                                    NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                        NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                                 NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                      \
# window_size                                                                                                                                                                                                                                                                                                                                  500
# method_and_year          parameters
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                               NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                               0.000 ± NA
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                          NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}         NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}             NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                  NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                         NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                 NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                 NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                               NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                   NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                            NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                 DA3  \
# window_size                                                                                                                                                                                                                                                                                                                                  210
# method_and_year          parameters
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                               NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                               0.098 ± NA
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                          NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}         NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}             NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                  NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                         NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                 NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                 NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                               NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                   NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                            NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                        84
# method_and_year          parameters
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                                    NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                     NaN
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.107 ± 1.6e-03
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                               NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}              NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}                  NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                       NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                              NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                      NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                      NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.000 ± 7.2e-08
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.000 ± NA
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.000 ± NA
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                       840
# method_and_year          parameters
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             1.192 ± NA
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.132 ± 1.6e-03
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                     NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.026 ± 1.3e-05
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.012 ± 2.7e-04
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.010 ± 7.4e-04
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.011 ± 7.1e-05
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  0.004 ± 2.4e-06
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.004 ± NA
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               0.002 ± NA
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                                    NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                        NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                                 NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                      Avg
# window_size
# method_and_year          parameters
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.597 ± NA
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.102 ± 1.7e-03
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.076 ± 8.2e-04
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                    0.049 ± NA
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.031 ± 2.0e-05
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.009 ± 1.4e-04
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.008 ± 3.7e-04
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.007 ± 5.2e-05
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  0.003 ± 7.6e-06
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.003 ± NA
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               0.001 ± NA
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.000 ± 4.7e-08
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.000 ± NA
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.000 ± NA

# %% [markdown]
# ## Summary Scoring Time of Online Anomaly Detectors with PV Datasets

# %%
# Pivot for mean - includes all data
mean_pivot = filtered_data.pivot_table(
    values="mean_scoring_time",
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="mean"
)

# Pivot for std - includes all data
# Note: This will be NaN for all 'N' rows, which is correct.
std_pivot = filtered_data.pivot_table(
    values="mean_scoring_time",
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="std"
)


# 2. Stack the DataFrames to align them as Series
mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
std_s = std_pivot.stack(level=[0, 1], dropna=False)

# 3. Apply the formatting function row-by-row
combined_s = pd.DataFrame({'mean': mean_s, 'std': std_s}).apply(
    lambda row: format_mean_std(row['mean'], row['std']), 
    axis=1
)

# 4. Unstack back into a DataFrame
combined = combined_s.unstack(level=[-2, -1])
# Ensure column order is the same as the original pivot
if not combined.empty:
    combined = combined.reindex(columns=mean_pivot.columns)
else:
    # Handle case where combined might be empty
    combined = pd.DataFrame(index=mean_pivot.index, columns=mean_pivot.columns)


# Get the numeric averages first (for sorting and formatting)
avg_mean = mean_pivot.mean(axis=1)
avg_std = std_pivot.mean(axis=1) # This will be NaN for 'N' rows

# 5. Apply the same formatting logic to the Avg column
avg_col_s = pd.DataFrame({'mean': avg_mean, 'std': avg_std}).apply(
    lambda row: format_mean_std(row['mean'], row['std']),
    axis=1
)

combined["Avg"] = avg_col_s

# 6. Sort by the *numeric* average mean (before it was a string)
combined = combined.loc[avg_mean.sort_values(ascending=False).index]

# 7. Display with HTML formatting in Jupyter
combined
# Out:
# /tmp/ipykernel_570305/3238025577.py:20: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
# /tmp/ipykernel_570305/3238025577.py:21: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   std_s = std_pivot.stack(level=[0, 1], dropna=False)
# cod_scenario                                                                                                                                                                                                                                                                                                                                      116  \
# window_size                                                                                                                                                                                                                                                                                                                                       200
# method_and_year          parameters
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.043 ± 1.4e-04
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}              NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}                  NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                     NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                               NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.000 ± NA
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                      NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.000 ± NA
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                       NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                                    NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                      NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.000 ± 8.8e-08
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                              NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                      2000
# method_and_year          parameters
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                     NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.030 ± 1.2e-04
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.030 ± 3.4e-05
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.010 ± 7.0e-05
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.009 ± 1.6e-05
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                                 NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               0.001 ± NA
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                        NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.001 ± 9.4e-06
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.000 ± NA
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.000 ± NA
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                                    NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  0.000 ± 1.1e-08
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                      \
# window_size                                                                                                                                                                                                                                                                                                                                  500
# method_and_year          parameters
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                               0.000 ± NA
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}         NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}             NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                          NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                            NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                 NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                   NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                  NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                               NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                 NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                               NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                         NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                 DA3  \
# window_size                                                                                                                                                                                                                                                                                                                                  210
# method_and_year          parameters
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                               0.091 ± NA
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}         NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}             NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                          NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                            NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                 NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                   NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                  NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                               NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                 NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                               NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                         NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                        84
# method_and_year          parameters
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.102 ± 1.4e-03
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}              NaN
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}                  NaN
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                                     NaN
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                               NaN
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.008 ± NA
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                                      NaN
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.002 ± NA
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                                       NaN
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                                    NaN
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                                      NaN
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.000 ± 3.5e-08
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                              NaN
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                           \
# window_size                                                                                                                                                                                                                                                                                                                                       840
# method_and_year          parameters
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                                     NaN
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                           NaN
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.041 ± 3.2e-04
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.039 ± 7.5e-04
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.022 ± 1.1e-04
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.005 ± 9.8e-06
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                                 NaN
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               0.003 ± NA
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                        NaN
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.000 ± 3.3e-05
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.000 ± NA
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.001 ± NA
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                                    NaN
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  0.000 ± 1.7e-09
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                      Avg
# window_size
# method_and_year          parameters
# XStream (2018)           {'depth': 25, 'n_chains': 100, 'num_components': 50}                                                                                                                                                                                                                                                         0.073 ± 7.9e-04
# KitNet (2018)            {'hidden_ratio': 0.9, 'learning_rate': 0.1, 'max_size_ae': 10}                                                                                                                                                                                                                                                    0.045 ± NA
# OBKNN (TZnorm) (2025)    {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}  0.035 ± 2.2e-04
# OBKNN (TNone) (2025)     {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.034 ± 3.9e-04
# OIF (2024)               {'growth_criterion': 'fixed', 'max_leaf_samples': 64, 'n_jobs': -1, 'num_trees': 64}                                                                                                                                                                                                                         0.016 ± 9.1e-05
# IFASD (2013)             {'initial_window_X': None}                                                                                                                                                                                                                                                                                   0.007 ± 1.3e-05
# SWLOF (2000)             {'k': 10, 'k_is_max': False, 'metric': 'euclidean', 'simplified': False}                                                                                                                                                                                                                                          0.004 ± NA
# EStorm (2007)            {'max_radius': 900}                                                                                                                                                                                                                                                                                               0.002 ± NA
# SWKNN (2000)             {'k': 10, 'k_is_max': False, 'max_node_size': 20, 'metric': 'cityblock', 'min_node_size': 5, 'split_sampling': 5}                                                                                                                                                                                                 0.001 ± NA
# RRCF (2016)              {'num_trees': 4, 'tree_size': 256}                                                                                                                                                                                                                                                                           0.001 ± 2.1e-05
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}                                                                                                                                                                                                                             0.000 ± NA
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}                                                                                                                                                                                                                               0.000 ± NA
# HStree (2011)            {'anomaly_threshold': 0.5, 'max_depth': 10, 'number_of_trees': 25, 'size_limit': 0.1}                                                                                                                                                                                                                        0.000 ± 6.2e-08
# RSHash (2011)            {'decay': 0.05, 'feature_maxes': [inf, 2000], 'feature_mins': [0], 'num_components': 50, 'num_hash_fns': 1}                                                                                                                                                                                                  0.000 ± 6.5e-09

# %% [markdown]
# # Analysis OBKNN

# %%
#COD_SCENARIO = 'DA3' #Cod of Datasets used for tuning: DA3, 116
filtered_data = data[data["method"].isin(["OBKNN (TNone)","OBKNN (TZnorm)" ])]
#filtered_data = filtered_data[filtered_data["cod_scenario"].isin([COD_SCENARIO])]

# %% [markdown]
# ## No Transformation

# %%
obknn_tnone = filtered_data[filtered_data['method_window_and_param'].str.contains("'transf': 'NONE'", na=False)]

# %%
# Pivot for mean - includes all data
mean_pivot = obknn_tnone.pivot_table(
    values="raw_pr_auc",
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="mean"
)

# Pivot for std - includes all data
# Note: This will be NaN for all 'N' rows, which is correct.
std_pivot = obknn_tnone.pivot_table(
    values="raw_pr_auc",
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="std"
)


# 2. Stack the DataFrames to align them as Series
mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
std_s = std_pivot.stack(level=[0, 1], dropna=False)

# 3. Apply the formatting function row-by-row
combined_s = pd.DataFrame({'mean': mean_s, 'std': std_s}).apply(
    lambda row: format_mean_std(row['mean'], row['std']), 
    axis=1
)

# 4. Unstack back into a DataFrame
combined = combined_s.unstack(level=[-2, -1])
# Ensure column order is the same as the original pivot
if not combined.empty:
    combined = combined.reindex(columns=mean_pivot.columns)
else:
    # Handle case where combined might be empty
    combined = pd.DataFrame(index=mean_pivot.index, columns=mean_pivot.columns)


# Get the numeric averages first (for sorting and formatting)
avg_mean = mean_pivot.mean(axis=1)
avg_std = std_pivot.mean(axis=1) # This will be NaN for 'N' rows

# 5. Apply the same formatting logic to the Avg column
avg_col_s = pd.DataFrame({'mean': avg_mean, 'std': avg_std}).apply(
    lambda row: format_mean_std(row['mean'], row['std']),
    axis=1
)

combined["Avg"] = avg_col_s

# 6. Sort by the *numeric* average mean (before it was a string)
combined = combined.loc[avg_mean.sort_values(ascending=False).index]

# 7. Display with HTML formatting in Jupyter
combined
# Out:
# /tmp/ipykernel_570305/1429427191.py:20: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
# /tmp/ipykernel_570305/1429427191.py:21: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   std_s = std_pivot.stack(level=[0, 1], dropna=False)
# cod_scenario                                                                                                                                                                                                                                                                                                                                   116  \
# window_size                                                                                                                                                                                                                                                                                                                                    200
# method_and_year      parameters
# OBKNN (TNone) (2025) {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.821 ± 2.2e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.708 ± 1.9e-01
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.813 ± 2.5e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.490 ± 2.8e-01
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.981 ± 5.4e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.988 ± 7.5e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.155 ± 5.1e-02
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.109 ± 1.8e-02
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.934 ± 4.2e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.935 ± 3.5e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.075 ± 1.0e-06
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.075 ± 0.0e+00
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.367 ± 1.4e-02
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.281 ± 1.5e-02
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.112 ± 2.0e-06
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.112 ± 0.0e+00
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                        \
# window_size                                                                                                                                                                                                                                                                                                                                   2000
# method_and_year      parameters
# OBKNN (TNone) (2025) {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.931 ± 5.2e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.937 ± 7.9e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.341 ± 1.6e-02
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.644 ± 2.5e-01
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.994 ± 2.1e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.978 ± 7.5e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.219 ± 1.1e-01
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.203 ± 7.7e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.891 ± 1.6e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.884 ± 7.6e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.033 ± 5.5e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.028 ± 3.4e-05
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.504 ± 7.9e-02
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.389 ± 8.7e-02
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.072 ± 1.1e-02
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.035 ± 4.0e-03
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                        \
# window_size                                                                                                                                                                                                                                                                                                                                    500
# method_and_year      parameters
# OBKNN (TNone) (2025) {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.046 ± 1.1e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.052 ± 4.4e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.147 ± 2.8e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.161 ± 2.3e-02
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.957 ± 1.1e-02
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.963 ± 8.6e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.074 ± 2.3e-02
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.055 ± 1.1e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.890 ± 1.8e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.895 ± 2.9e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.054 ± 1.0e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.052 ± 0.0e+00
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.265 ± 8.1e-02
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.263 ± 5.5e-02
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.083 ± 1.0e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.076 ± 1.8e-07
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                   DA3  \
# window_size                                                                                                                                                                                                                                                                                                                                    210
# method_and_year      parameters
# OBKNN (TNone) (2025) {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.999 ± 1.8e-05
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.999 ± 2.3e-06
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.999 ± 8.7e-05
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.999 ± 2.3e-05
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.218 ± 5.5e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.219 ± 5.8e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.999 ± 1.2e-06
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.999 ± 9.0e-07
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.163 ± 2.9e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.164 ± 1.0e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.999 ± 2.8e-05
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.999 ± 4.0e-06
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.164 ± 2.6e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.164 ± 1.8e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.308 ± 7.2e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.310 ± 1.0e-03
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                        \
# window_size                                                                                                                                                                                                                                                                                                                                     84
# method_and_year      parameters
# OBKNN (TNone) (2025) {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.999 ± 8.8e-06
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.999 ± 0.0e+00
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.999 ± 1.3e-06
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.999 ± 1.8e-06
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.199 ± 4.2e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.200 ± 1.7e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.999 ± 0.0e+00
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.999 ± 0.0e+00
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.152 ± 1.1e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.152 ± 6.6e-05
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.999 ± 0.0e+00
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.999 ± 0.0e+00
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.152 ± 3.7e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.152 ± 1.8e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.308 ± 5.1e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.309 ± 4.0e-04
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                        \
# window_size                                                                                                                                                                                                                                                                                                                                    840
# method_and_year      parameters
# OBKNN (TNone) (2025) {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.999 ± 2.0e-05
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.999 ± 1.1e-05
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.999 ± 1.1e-06
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.999 ± 3.2e-06
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.268 ± 7.1e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.266 ± 1.4e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.999 ± 9.8e-06
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.999 ± 1.8e-06
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.195 ± 4.4e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.196 ± 4.8e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.999 ± 1.4e-05
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.999 ± 4.7e-06
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.194 ± 7.2e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.193 ± 5.4e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.307 ± 1.6e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.308 ± 2.1e-03
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                   Avg
# window_size
# method_and_year      parameters
# OBKNN (TNone) (2025) {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.799 ± 1.1e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.782 ± 3.4e-02
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.716 ± 3.6e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.715 ± 9.3e-02
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.603 ± 3.4e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.602 ± 2.8e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.574 ± 3.1e-02
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.561 ± 4.4e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.538 ± 7.8e-04
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.538 ± 1.9e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.526 ± 1.1e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.525 ± 7.2e-06
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.274 ± 2.9e-02
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.240 ± 2.6e-02
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.198 ± 2.5e-03
#                      {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'NONE', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.192 ± 1.3e-03

# %% [markdown]
# ## ZNORM Transformation

# %%
obknn_tznorm = filtered_data[filtered_data['method_window_and_param'].str.contains("'transf': 'ZNORM'", na=False)]

# %%
# Pivot for mean - includes all data
mean_pivot = obknn_tznorm.pivot_table(
    values="raw_pr_auc",
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="mean"
)

# Pivot for std - includes all data
# Note: This will be NaN for all 'N' rows, which is correct.
std_pivot = obknn_tznorm.pivot_table(
    values="raw_pr_auc",
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="std"
)


# 2. Stack the DataFrames to align them as Series
mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
std_s = std_pivot.stack(level=[0, 1], dropna=False)

# 3. Apply the formatting function row-by-row
combined_s = pd.DataFrame({'mean': mean_s, 'std': std_s}).apply(
    lambda row: format_mean_std(row['mean'], row['std']), 
    axis=1
)

# 4. Unstack back into a DataFrame
combined = combined_s.unstack(level=[-2, -1])
# Ensure column order is the same as the original pivot
if not combined.empty:
    combined = combined.reindex(columns=mean_pivot.columns)
else:
    # Handle case where combined might be empty
    combined = pd.DataFrame(index=mean_pivot.index, columns=mean_pivot.columns)


# Get the numeric averages first (for sorting and formatting)
avg_mean = mean_pivot.mean(axis=1)
avg_std = std_pivot.mean(axis=1) # This will be NaN for 'N' rows

# 5. Apply the same formatting logic to the Avg column
avg_col_s = pd.DataFrame({'mean': avg_mean, 'std': avg_std}).apply(
    lambda row: format_mean_std(row['mean'], row['std']),
    axis=1
)

combined["Avg"] = avg_col_s

# 6. Sort by the *numeric* average mean (before it was a string)
combined = combined.loc[avg_mean.sort_values(ascending=False).index]

# 7. Display with HTML formatting in Jupyter
combined
# Out:
# /tmp/ipykernel_570305/2794823263.py:20: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
# /tmp/ipykernel_570305/2794823263.py:21: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   std_s = std_pivot.stack(level=[0, 1], dropna=False)
# cod_scenario                                                                                                                                                                                                                                                                                                                                     116  \
# window_size                                                                                                                                                                                                                                                                                                                                      200
# method_and_year       parameters
# OBKNN (TZnorm) (2025) {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.966 ± 8.2e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.966 ± 5.5e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.965 ± 3.2e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.970 ± 1.1e-02
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.804 ± 1.2e-02
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.659 ± 2.2e-01
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.345 ± 2.4e-01
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.063 ± 3.8e-04
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.033 ± 1.1e-05
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.033 ± 0.0e+00
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.101 ± 7.6e-02
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.046 ± 7.2e-06
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.046 ± 0.0e+00
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.037 ± 1.2e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.039 ± 1.9e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.119 ± 7.4e-04
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                          \
# window_size                                                                                                                                                                                                                                                                                                                                     2000
# method_and_year       parameters
# OBKNN (TZnorm) (2025) {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.934 ± 8.6e-04
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.936 ± 3.7e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.991 ± 5.8e-04
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.962 ± 5.4e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.827 ± 2.1e-02
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.804 ± 1.0e-02
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.495 ± 7.0e-02
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.551 ± 3.4e-04
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.042 ± 7.6e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.031 ± 5.6e-05
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.128 ± 4.9e-02
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.058 ± 1.7e-02
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.033 ± 7.3e-04
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.031 ± 5.9e-05
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.039 ± 5.3e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.050 ± 9.5e-03
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                          \
# window_size                                                                                                                                                                                                                                                                                                                                      500
# method_and_year       parameters
# OBKNN (TZnorm) (2025) {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.958 ± 9.1e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.951 ± 2.0e-02
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.962 ± 6.6e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.960 ± 7.6e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.916 ± 6.0e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.925 ± 1.9e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.090 ± 9.2e-02
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.070 ± 4.1e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.031 ± 1.1e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.030 ± 0.0e+00
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.062 ± 1.9e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.042 ± 1.9e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.039 ± 0.0e+00
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.031 ± 0.0e+00
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.032 ± 8.6e-04
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.055 ± 5.8e-03
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                     DA3  \
# window_size                                                                                                                                                                                                                                                                                                                                      210
# method_and_year       parameters
# OBKNN (TZnorm) (2025) {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.110 ± 2.0e-05
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.110 ± 7.0e-05
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.089 ± 8.1e-06
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.089 ± 4.8e-06
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.095 ± 1.8e-05
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.095 ± 1.5e-05
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.088 ± 4.5e-05
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.088 ± 5.9e-06
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.217 ± 9.7e-04
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.217 ± 1.3e-04
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.164 ± 1.5e-04
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.200 ± 4.4e-04
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.201 ± 3.5e-04
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.205 ± 3.2e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.199 ± 2.6e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.164 ± 3.6e-04
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                          \
# window_size                                                                                                                                                                                                                                                                                                                                       84
# method_and_year       parameters
# OBKNN (TZnorm) (2025) {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.109 ± 1.8e-05
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.109 ± 4.7e-05
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.087 ± 7.8e-06
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.087 ± 1.2e-05
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.094 ± 2.8e-05
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.094 ± 3.2e-06
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.087 ± 2.1e-05
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.087 ± 1.5e-05
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.247 ± 2.5e-04
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.248 ± 1.4e-05
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.163 ± 5.6e-04
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.218 ± 6.4e-04
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.220 ± 4.6e-04
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.207 ± 2.7e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.197 ± 1.3e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.164 ± 5.4e-04
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                          \
# window_size                                                                                                                                                                                                                                                                                                                                      840
# method_and_year       parameters
# OBKNN (TZnorm) (2025) {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.132 ± 6.4e-06
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.132 ± 1.6e-04
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.106 ± 2.6e-04
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.106 ± 1.7e-05
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.111 ± 8.1e-05
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.111 ± 8.4e-06
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.106 ± 1.7e-05
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.106 ± 4.3e-05
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.263 ± 3.1e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.263 ± 2.6e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.200 ± 1.2e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.240 ± 2.6e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.241 ± 5.6e-04
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.261 ± 1.4e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.252 ± 5.1e-04
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.200 ± 9.3e-04
#
# cod_scenario                                                                                                                                                                                                                                                                                                                                     Avg
# window_size
# method_and_year       parameters
# OBKNN (TZnorm) (2025) {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.535 ± 3.0e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.534 ± 5.0e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.533 ± 1.8e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.529 ± 4.0e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.474 ± 6.5e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.448 ± 3.9e-02
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.202 ± 6.8e-02
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.05, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.161 ± 8.2e-04
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}   0.139 ± 2.2e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'welford'}  0.137 ± 4.7e-04
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}        0.136 ± 2.1e-02
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}    0.134 ± 3.7e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'welford'}   0.130 ± 3.5e-04
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}      0.129 ± 1.4e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 30, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': False, 'update_mode_stats': 'ema'}       0.126 ± 2.1e-03
#                       {'algorithm': 'brute', 'alpha_ema': 0.01, 'alpha_z_test': 0.95, 'chunk_size': 30, 'dmetric': 'cityblock', 'ensemble_size': 240, 'n_jobs': -1, 'no_bootstrapp': False, 'no_z_score': False, 'transf': 'ZNORM', 'type_dist': 'largest', 'update_distance_with_abnormal': True, 'update_mode_stats': 'ema'}       0.125 ± 3.0e-03

# %% [markdown]
# # Analysis mDragstream

# %%
#COD_SCENARIO = 'DA3' #Cod of Datasets used for tuning: DA3, 116
filtered_data = data[data["method"].isin(["mDragStream (Euc)","mDragStream (Mah)" ])]
#filtered_data = filtered_data[filtered_data["cod_scenario"].isin([COD_SCENARIO])]

# %% [markdown]
# ## Euclidean Distance

# %%
euclidean_mdragstream = filtered_data[filtered_data['method_window_and_param'].str.contains("'metric': 'euclidean'", na=False)]

# %%
# Pivot for mean - includes all data
mean_pivot = euclidean_mdragstream.pivot_table(
    values="raw_pr_auc",
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="mean"
)

# Pivot for std - includes all data
# Note: This will be NaN for all 'N' rows, which is correct.
std_pivot = euclidean_mdragstream.pivot_table(
    values="raw_pr_auc",
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="std"
)


# 2. Stack the DataFrames to align them as Series
mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
std_s = std_pivot.stack(level=[0, 1], dropna=False)

# 3. Apply the formatting function row-by-row
combined_s = pd.DataFrame({'mean': mean_s, 'std': std_s}).apply(
    lambda row: format_mean_std(row['mean'], row['std']), 
    axis=1
)

# 4. Unstack back into a DataFrame
combined = combined_s.unstack(level=[-2, -1])
# Ensure column order is the same as the original pivot
if not combined.empty:
    combined = combined.reindex(columns=mean_pivot.columns)
else:
    # Handle case where combined might be empty
    combined = pd.DataFrame(index=mean_pivot.index, columns=mean_pivot.columns)


# Get the numeric averages first (for sorting and formatting)
avg_mean = mean_pivot.mean(axis=1)
avg_std = std_pivot.mean(axis=1) # This will be NaN for 'N' rows

# 5. Apply the same formatting logic to the Avg column
avg_col_s = pd.DataFrame({'mean': avg_mean, 'std': avg_std}).apply(
    lambda row: format_mean_std(row['mean'], row['std']),
    axis=1
)

combined["Avg"] = avg_col_s

# 6. Sort by the *numeric* average mean (before it was a string)
combined = combined.loc[avg_mean.sort_values(ascending=False).index]

# 7. Display with HTML formatting in Jupyter
combined
# Out:
# /tmp/ipykernel_570305/965129032.py:20: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
# /tmp/ipykernel_570305/965129032.py:21: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   std_s = std_pivot.stack(level=[0, 1], dropna=False)
# cod_scenario                                                                                                         116  \
# window_size                                                                                                          200
# method_and_year          parameters
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}  0.034 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'euclidean'}  0.034 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'euclidean'}  0.034 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'euclidean'}  0.034 ± NA
#
# cod_scenario                                                                                                              \
# window_size                                                                                                         2000
# method_and_year          parameters
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}  0.038 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'euclidean'}  0.038 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'euclidean'}  0.029 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'euclidean'}  0.029 ± NA
#
# cod_scenario                                                                                                              \
# window_size                                                                                                          500
# method_and_year          parameters
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}  0.055 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'euclidean'}  0.055 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'euclidean'}  0.034 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'euclidean'}  0.034 ± NA
#
# cod_scenario                                                                                                         DA3  \
# window_size                                                                                                          210
# method_and_year          parameters
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}  0.694 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'euclidean'}  0.694 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'euclidean'}  0.663 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'euclidean'}  0.663 ± NA
#
# cod_scenario                                                                                                              \
# window_size                                                                                                           84
# method_and_year          parameters
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}  0.919 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'euclidean'}  0.919 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'euclidean'}  0.673 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'euclidean'}  0.673 ± NA
#
# cod_scenario                                                                                                              \
# window_size                                                                                                          840
# method_and_year          parameters
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}  0.926 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'euclidean'}  0.926 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'euclidean'}  0.886 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'euclidean'}  0.886 ± NA
#
# cod_scenario                                                                                                         Avg
# window_size
# method_and_year          parameters
# mDragStream (Euc) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'euclidean'}  0.444 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'euclidean'}  0.444 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'euclidean'}  0.387 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'euclidean'}  0.387 ± NA

# %% [markdown]
# ## Mahalanobis Distance

# %%
mahalanobis_mdragstream = filtered_data[filtered_data['method_window_and_param'].str.contains("'metric': 'mahalanobis'", na=False)]

# %%
# Pivot for mean - includes all data
mean_pivot = mahalanobis_mdragstream.pivot_table(
    values="raw_pr_auc",
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="mean"
)

# Pivot for std - includes all data
# Note: This will be NaN for all 'N' rows, which is correct.
std_pivot = mahalanobis_mdragstream.pivot_table(
    values="raw_pr_auc",
    columns=["cod_scenario", "window_size"],
    index=["method_and_year", "parameters"],
    aggfunc="std"
)


# 2. Stack the DataFrames to align them as Series
mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
std_s = std_pivot.stack(level=[0, 1], dropna=False)

# 3. Apply the formatting function row-by-row
combined_s = pd.DataFrame({'mean': mean_s, 'std': std_s}).apply(
    lambda row: format_mean_std(row['mean'], row['std']), 
    axis=1
)

# 4. Unstack back into a DataFrame
combined = combined_s.unstack(level=[-2, -1])
# Ensure column order is the same as the original pivot
if not combined.empty:
    combined = combined.reindex(columns=mean_pivot.columns)
else:
    # Handle case where combined might be empty
    combined = pd.DataFrame(index=mean_pivot.index, columns=mean_pivot.columns)


# Get the numeric averages first (for sorting and formatting)
avg_mean = mean_pivot.mean(axis=1)
avg_std = std_pivot.mean(axis=1) # This will be NaN for 'N' rows

# 5. Apply the same formatting logic to the Avg column
avg_col_s = pd.DataFrame({'mean': avg_mean, 'std': avg_std}).apply(
    lambda row: format_mean_std(row['mean'], row['std']),
    axis=1
)

combined["Avg"] = avg_col_s

# 6. Sort by the *numeric* average mean (before it was a string)
combined = combined.loc[avg_mean.sort_values(ascending=False).index]

# 7. Display with HTML formatting in Jupyter
combined
# Out:
# /tmp/ipykernel_570305/2710109500.py:20: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   mean_s = mean_pivot.stack(level=[0, 1], dropna=False)
# /tmp/ipykernel_570305/2710109500.py:21: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   std_s = std_pivot.stack(level=[0, 1], dropna=False)
# cod_scenario                                                                                                           116  \
# window_size                                                                                                            200
# method_and_year          parameters
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}  0.029 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'mahalanobis'}  0.029 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'mahalanobis'}  0.025 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'mahalanobis'}  0.025 ± NA
#
# cod_scenario                                                                                                                \
# window_size                                                                                                           2000
# method_and_year          parameters
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}  0.034 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'mahalanobis'}  0.034 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'mahalanobis'}  0.032 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'mahalanobis'}  0.032 ± NA
#
# cod_scenario                                                                                                                \
# window_size                                                                                                            500
# method_and_year          parameters
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}  0.029 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'mahalanobis'}  0.029 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'mahalanobis'}  0.029 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'mahalanobis'}  0.029 ± NA
#
# cod_scenario                                                                                                           DA3  \
# window_size                                                                                                            210
# method_and_year          parameters
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}  0.998 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'mahalanobis'}  0.998 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'mahalanobis'}  0.998 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'mahalanobis'}  0.998 ± NA
#
# cod_scenario                                                                                                                \
# window_size                                                                                                             84
# method_and_year          parameters
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}  0.999 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'mahalanobis'}  0.999 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'mahalanobis'}  0.999 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'mahalanobis'}  0.999 ± NA
#
# cod_scenario                                                                                                                \
# window_size                                                                                                            840
# method_and_year          parameters
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}  0.998 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'mahalanobis'}  0.998 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'mahalanobis'}  0.998 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'mahalanobis'}  0.998 ± NA
#
# cod_scenario                                                                                                           Avg
# window_size
# method_and_year          parameters
# mDragStream (Mah) (2025) {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 30, 'metric': 'mahalanobis'}  0.515 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 30, 'maxNbClusters': 50, 'metric': 'mahalanobis'}  0.515 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 30, 'metric': 'mahalanobis'}  0.514 ± NA
#                          {'inv_cov': None, 'maxClusterSize': 50, 'maxNbClusters': 50, 'metric': 'mahalanobis'}  0.514 ± NA
